# %%
# !export SPOTIPY_CLIENT_ID='63594c9b2f99411a8cbd18df04851fc4'

# %%
# !export SPOTIPY_CLIENT_SECRET='096168b2bd1f4378ae410726955c9ed8'

# %%
# !export SPOTIPY_REDIRECT_URI='https://www.google.com/'

# %%
# ! SPOTIPY_CLIENT_ID
# Out:
# /bin/sh: SPOTIPY_CLIENT_ID: command not found

# %%
import os
import sys
import json
import spotipy
import webbrowser
import spotipy.util as util
from json.decoder import JSONDecodeError

USERNAME = 'basslaughter' #your spotify username
CLIENT_ID = '63594c9b2f99411a8cbd18df04851fc4' #set at your developer account
CLIENT_SECRET = '096168b2bd1f4378ae410726955c9ed8' #set at your developer account
REDIRECT_URI = 'http://google.com/' #set at your developer account, usually "http://localhost:8000"
SCOPE = 'user-library-read' # or else
# ps. REDIRECT_URI is crucial here. if http://localhost:8000 is not set, or with a single '/' misplaced, it will generate a connection error.

# then pass them:

token = util.prompt_for_user_token(username = USERNAME, 
                                   scope = SCOPE, 
                                   client_id = CLIENT_ID, 
                                   client_secret = CLIENT_SECRET, 
                                   redirect_uri = REDIRECT_URI)

if token:
   sp = spotipy.Spotify(auth=token)

# %%
token
# Out:
# 'BQCFw6c8mbhbrRhloc1eKRUzc7FqF2tFROc0SF7je07DiVIB4uosYNqxh8KsBs8-ypBnibBchF-1DyFn-dtee8NHYugxHVQcc8GBS4qGcsuXkUSb9WEr2gSRFJEfqDegUYOGJJsF_t6QIHX8Iio_HdsRlClW0L6-LOJdYvr4otMB5H5m6QopDKYGaeBMb07sq0zvoN_G-A'

# %%
sp = spotipy.Spotify(auth=token)
results = sp.current_user_saved_tracks()
for item in results['items']:
    track = item['track']
    print (track['name'] + ' - ' + track['artists'][0]['name'])
# Out:
# Suite No. 2 in D Minor, BWV 1008: V. Menuet & VI. Menuet - Johann Sebastian Bach
# Mass in B Minor, BWV 232: Sanctus - Johann Sebastian Bach
# Consume - Original Mix - Plastikman
# Pavane - 2018 Remaster - The Legendary Pink Dots
# Red Flag - The Legendary Pink Dots
# Jenseits - Lumisokea
# Abri - Lumisokea
# Nanissáanah - Lumisokea
# King of Hosts - Tzusing
# Tremor - Original Mix - Current Value
# 日出東方 唯我不敗 - Tzusing
# Dead Communication - Current Value
# Eleven - Lumisokea
# Dotted - Lumisokea
# Nobu - Herbie Hancock
# Make The Call - AFRODEUTSCHE
# Superstar - Bou
# Veteran - Bou
# Shudehill - SHOTTY HORROH
# Conjouring - IAMDDB

# %%
content = {"token": "BQCFw6c8mbhbrRhloc1eKRUzc7FqF2tFROc0SF7je07DiVIB4uosYNqxh8KsBs8-ypBnibBchF-1DyFn-dtee8NHYugxHVQcc8GBS4qGcsuXkUSb9WEr2gSRFJEfqDegUYOGJJsF_t6QIHX8Iio_HdsRlClW0L6-LOJdYvr4otMB5H5m6QopDKYGaeBMb07sq0zvoN_G-A"
}

# %%
content["token"]
# Out:
# 'BQCFw6c8mbhbrRhloc1eKRUzc7FqF2tFROc0SF7je07DiVIB4uosYNqxh8KsBs8-ypBnibBchF-1DyFn-dtee8NHYugxHVQcc8GBS4qGcsuXkUSb9WEr2gSRFJEfqDegUYOGJJsF_t6QIHX8Iio_HdsRlClW0L6-LOJdYvr4otMB5H5m6QopDKYGaeBMb07sq0zvoN_G-A'

# %%
results
# Out:
# {'href': 'https://api.spotify.com/v1/me/tracks?offset=0&limit=20',
#  'items': [{'added_at': '2020-01-15T23:01:10Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#        'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#        'id': '5aIqB5nVVvmFsvSdExz408',
#        'name': 'Johann Sebastian Bach',
#        'type': 'artist',
#        'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0VcuiNXzYUupLKGZtWg2wF'},
#        'href': 'https://api.spotify.com/v1/artists/0VcuiNXzYUupLKGZtWg2wF',
#        'id': '0VcuiNXzYUupLKGZtWg2wF',
#        'name': 'Lucia Swarts',
#        'type': 'artist',
#        'uri': 'spotify:artist:0VcuiNXzYUupLKGZtWg2wF'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5Ulg96KhnppXvYKngbRiLH'},
#      'href': 'https://api.spotify.com/v1/albums/5Ulg96KhnppXvYKngbRiLH',
#      'id': '5Ulg96KhnppXvYKngbRiLH',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27352d38015881327daf54c3349',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0252d38015881327daf54c3349',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485152d38015881327daf54c3349',
#        'width': 64}],
#      'name': 'Six Suites for Violoncello Solo, BWV 1007-1012',
#      'release_date': '2019-03-08',
#      'release_date_precision': 'day',
#      'total_tracks': 36,
#      'type': 'album',
#      'uri': 'spotify:album:5Ulg96KhnppXvYKngbRiLH'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#       'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#       'id': '5aIqB5nVVvmFsvSdExz408',
#       'name': 'Johann Sebastian Bach',
#       'type': 'artist',
#       'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0VcuiNXzYUupLKGZtWg2wF'},
#       'href': 'https://api.spotify.com/v1/artists/0VcuiNXzYUupLKGZtWg2wF',
#       'id': '0VcuiNXzYUupLKGZtWg2wF',
#       'name': 'Lucia Swarts',
#       'type': 'artist',
#       'uri': 'spotify:artist:0VcuiNXzYUupLKGZtWg2wF'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 213346,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLB151900045'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1Qg7tAfpy2tuvJ4WSDv247'},
#     'href': 'https://api.spotify.com/v1/tracks/1Qg7tAfpy2tuvJ4WSDv247',
#     'id': '1Qg7tAfpy2tuvJ4WSDv247',
#     'is_local': False,
#     'name': 'Suite No. 2 in D Minor, BWV 1008: V. Menuet & VI. Menuet',
#     'popularity': 4,
#     'preview_url': 'https://p.scdn.co/mp3-preview/483be1aa8a0055a06706c709cf5222d03eedfce3?cid=63594c9b2f99411a8cbd18df04851fc4',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:1Qg7tAfpy2tuvJ4WSDv247'}},
#   {'added_at': '2020-01-15T22:59:14Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#        'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#        'id': '5aIqB5nVVvmFsvSdExz408',
#        'name': 'Johann Sebastian Bach',
#        'type': 'artist',
#        'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AU',
#       'BG',
#       'CA',
#       'CY',
#       'CZ',
#       'DO',
#       'DZ',
#       'EE',
#       'EG',
#       'GB',
#       'GR',
#       'HK',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'JO',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MY',
#       'NZ',
#       'OM',
#       'PH',
#       'PL',
#       'PS',
#       'QA',
#       'RO',
#       'SA',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'US',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6jbwqAAiq8nsBoNNY56UuS'},
#      'href': 'https://api.spotify.com/v1/albums/6jbwqAAiq8nsBoNNY56UuS',
#      'id': '6jbwqAAiq8nsBoNNY56UuS',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27338c195e57113e22342e04d1c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0238c195e57113e22342e04d1c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485138c195e57113e22342e04d1c',
#        'width': 64}],
#      'name': 'J.S. Bach Mass in B Minor',
#      'release_date': '2018-10-12',
#      'release_date_precision': 'day',
#      'total_tracks': 25,
#      'type': 'album',
#      'uri': 'spotify:album:6jbwqAAiq8nsBoNNY56UuS'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#       'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#       'id': '5aIqB5nVVvmFsvSdExz408',
#       'name': 'Johann Sebastian Bach',
#       'type': 'artist',
#       'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2ozcTa5tl8qhSbhJKM60I5'},
#       'href': 'https://api.spotify.com/v1/artists/2ozcTa5tl8qhSbhJKM60I5',
#       'id': '2ozcTa5tl8qhSbhJKM60I5',
#       'name': 'Philippe Herreweghe',
#       'type': 'artist',
#       'uri': 'spotify:artist:2ozcTa5tl8qhSbhJKM60I5'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/17BdLN9q8RRQQqyklLwac1'},
#       'href': 'https://api.spotify.com/v1/artists/17BdLN9q8RRQQqyklLwac1',
#       'id': '17BdLN9q8RRQQqyklLwac1',
#       'name': 'Collegium Vocale Gent',
#       'type': 'artist',
#       'uri': 'spotify:artist:17BdLN9q8RRQQqyklLwac1'}],
#     'available_markets': ['AD',
#      'AE',
#      'AU',
#      'BG',
#      'CA',
#      'CY',
#      'CZ',
#      'DO',
#      'DZ',
#      'EE',
#      'EG',
#      'GB',
#      'GR',
#      'HK',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'JO',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MY',
#      'NZ',
#      'OM',
#      'PH',
#      'PL',
#      'PS',
#      'QA',
#      'RO',
#      'SA',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'US',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 293333,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYC8801803'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1FDNASh3QfLrG2N7vNoBOw'},
#     'href': 'https://api.spotify.com/v1/tracks/1FDNASh3QfLrG2N7vNoBOw',
#     'id': '1FDNASh3QfLrG2N7vNoBOw',
#     'is_local': False,
#     'name': 'Mass in B Minor, BWV 232: Sanctus',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6d30fbeae87bb881c0e152a5e9092a585ad21ed9?cid=63594c9b2f99411a8cbd18df04851fc4',
#     'track_number': 20,
#     'type': 'track',
#     'uri': 'spotify:track:1FDNASh3QfLrG2N7vNoBOw'}},
#   {'added_at': '2019-12-25T17:15:52Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7GoFQNOTX0suC6Tn59qx8n'},
#        'href': 'https://api.spotify.com/v1/artists/7GoFQNOTX0suC6Tn59qx8n',
#        'id': '7GoFQNOTX0suC6Tn59qx8n',
#        'name': 'Plastikman',
#        'type': 'artist',
#        'uri': 'spotify:artist:7GoFQNOTX0suC6Tn59qx8n'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0In0JVMLKpMGbsOofd1Hm8'},
#      'href': 'https://api.spotify.com/v1/albums/0In0JVMLKpMGbsOofd1Hm8',
#      'id': '0In0JVMLKpMGbsOofd1Hm8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27344da868a12c24662648cef88',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0244da868a12c24662648cef88',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485144da868a12c24662648cef88',
#        'width': 64}],
#      'name': 'Consumed',
#      'release_date': '1998-05-19',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0In0JVMLKpMGbsOofd1Hm8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7GoFQNOTX0suC6Tn59qx8n'},
#       'href': 'https://api.spotify.com/v1/artists/7GoFQNOTX0suC6Tn59qx8n',
#       'id': '7GoFQNOTX0suC6Tn59qx8n',
#       'name': 'Plastikman',
#       'type': 'artist',
#       'uri': 'spotify:artist:7GoFQNOTX0suC6Tn59qx8n'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 678933,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAM269850001'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/11HpNMd6I6cpi64Y36U3ju'},
#     'href': 'https://api.spotify.com/v1/tracks/11HpNMd6I6cpi64Y36U3ju',
#     'id': '11HpNMd6I6cpi64Y36U3ju',
#     'is_local': False,
#     'name': 'Consume - Original Mix',
#     'popularity': 16,
#     'preview_url': 'https://p.scdn.co/mp3-preview/95b88b5545df9ccd75abc97186416a0152be2bcb?cid=63594c9b2f99411a8cbd18df04851fc4',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:11HpNMd6I6cpi64Y36U3ju'}},
#   {'added_at': '2019-10-26T20:55:11Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55XX7sgmxtVFNJnHrQMXh5'},
#        'href': 'https://api.spotify.com/v1/artists/55XX7sgmxtVFNJnHrQMXh5',
#        'id': '55XX7sgmxtVFNJnHrQMXh5',
#        'name': 'The Legendary Pink Dots',
#        'type': 'artist',
#        'uri': 'spotify:artist:55XX7sgmxtVFNJnHrQMXh5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6W32wqIRInZk3BbCnWkS28'},
#      'href': 'https://api.spotify.com/v1/albums/6W32wqIRInZk3BbCnWkS28',
#      'id': '6W32wqIRInZk3BbCnWkS28',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b9a839e854e244fcca6122d2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b9a839e854e244fcca6122d2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b9a839e854e244fcca6122d2',
#        'width': 64}],
#      'name': 'Malachai (Shadow Weaver Pt. 2) [2018 Remaster]',
#      'release_date': '2019-02-22',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:6W32wqIRInZk3BbCnWkS28'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55XX7sgmxtVFNJnHrQMXh5'},
#       'href': 'https://api.spotify.com/v1/artists/55XX7sgmxtVFNJnHrQMXh5',
#       'id': '55XX7sgmxtVFNJnHrQMXh5',
#       'name': 'The Legendary Pink Dots',
#       'type': 'artist',
#       'uri': 'spotify:artist:55XX7sgmxtVFNJnHrQMXh5'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 304000,
#     'explicit': False,
#     'external_ids': {'isrc': 'US57M1817204'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2F1XmP93IwOwhBo5gOhwqt'},
#     'href': 'https://api.spotify.com/v1/tracks/2F1XmP93IwOwhBo5gOhwqt',
#     'id': '2F1XmP93IwOwhBo5gOhwqt',
#     'is_local': False,
#     'name': 'Pavane - 2018 Remaster',
#     'popularity': 5,
#     'preview_url': 'https://p.scdn.co/mp3-preview/392fcc76069d5cf22181d223ca5a99ed01fe644a?cid=63594c9b2f99411a8cbd18df04851fc4',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2F1XmP93IwOwhBo5gOhwqt'}},
#   {'added_at': '2019-10-26T20:51:02Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55XX7sgmxtVFNJnHrQMXh5'},
#        'href': 'https://api.spotify.com/v1/artists/55XX7sgmxtVFNJnHrQMXh5',
#        'id': '55XX7sgmxtVFNJnHrQMXh5',
#        'name': 'The Legendary Pink Dots',
#        'type': 'artist',
#        'uri': 'spotify:artist:55XX7sgmxtVFNJnHrQMXh5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5N5CLSUw3Uthvh0UrwnR83'},
#      'href': 'https://api.spotify.com/v1/albums/5N5CLSUw3Uthvh0UrwnR83',
#      'id': '5N5CLSUw3Uthvh0UrwnR83',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ef5f0091f9a6f02427510ebe',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ef5f0091f9a6f02427510ebe',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ef5f0091f9a6f02427510ebe',
#        'width': 64}],
#      'name': 'Angel in the Detail',
#      'release_date': '2019-08-23',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5N5CLSUw3Uthvh0UrwnR83'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55XX7sgmxtVFNJnHrQMXh5'},
#       'href': 'https://api.spotify.com/v1/artists/55XX7sgmxtVFNJnHrQMXh5',
#       'id': '55XX7sgmxtVFNJnHrQMXh5',
#       'name': 'The Legendary Pink Dots',
#       'type': 'artist',
#       'uri': 'spotify:artist:55XX7sgmxtVFNJnHrQMXh5'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 666000,
#     'explicit': False,
#     'external_ids': {'isrc': 'US57M1919010'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4oPq32lOh8Eg5kkdzt1VMp'},
#     'href': 'https://api.spotify.com/v1/tracks/4oPq32lOh8Eg5kkdzt1VMp',
#     'id': '4oPq32lOh8Eg5kkdzt1VMp',
#     'is_local': False,
#     'name': 'Red Flag',
#     'popularity': 7,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c9e673e93625ee7c0c616e8934107f4b669fbb12?cid=63594c9b2f99411a8cbd18df04851fc4',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:4oPq32lOh8Eg5kkdzt1VMp'}},
#   {'added_at': '2019-08-29T00:16:15Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5467S01XgF4JNYDS5eynEZ'},
#        'href': 'https://api.spotify.com/v1/artists/5467S01XgF4JNYDS5eynEZ',
#        'id': '5467S01XgF4JNYDS5eynEZ',
#        'name': 'Lumisokea',
#        'type': 'artist',
#        'uri': 'spotify:artist:5467S01XgF4JNYDS5eynEZ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/62yzkUYnhehn1cMlRHpegF'},
#      'href': 'https://api.spotify.com/v1/albums/62yzkUYnhehn1cMlRHpegF',
#      'id': '62yzkUYnhehn1cMlRHpegF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a3c835234e54cda9cf4951bc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a3c835234e54cda9cf4951bc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a3c835234e54cda9cf4951bc',
#        'width': 64}],
#      'name': 'Mnemosyne',
#      'release_date': '2015-09-04',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:62yzkUYnhehn1cMlRHpegF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5467S01XgF4JNYDS5eynEZ'},
#       'href': 'https://api.spotify.com/v1/artists/5467S01XgF4JNYDS5eynEZ',
#       'id': '5467S01XgF4JNYDS5eynEZ',
#       'name': 'Lumisokea',
#       'type': 'artist',
#       'uri': 'spotify:artist:5467S01XgF4JNYDS5eynEZ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 361042,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBHLW1501730'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5lZ5FU8kf7vyOlECQmtw4u'},
#     'href': 'https://api.spotify.com/v1/tracks/5lZ5FU8kf7vyOlECQmtw4u',
#     'id': '5lZ5FU8kf7vyOlECQmtw4u',
#     'is_local': False,
#     'name': 'Jenseits',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6d2eb343e7f6e4bad0c7252e7cdd22446e4445fc?cid=63594c9b2f99411a8cbd18df04851fc4',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:5lZ5FU8kf7vyOlECQmtw4u'}},
#   {'added_at': '2019-08-29T00:04:17Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5467S01XgF4JNYDS5eynEZ'},
#        'href': 'https://api.spotify.com/v1/artists/5467S01XgF4JNYDS5eynEZ',
#        'id': '5467S01XgF4JNYDS5eynEZ',
#        'name': 'Lumisokea',
#        'type': 'artist',
#        'uri': 'spotify:artist:5467S01XgF4JNYDS5eynEZ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/62yzkUYnhehn1cMlRHpegF'},
#      'href': 'https://api.spotify.com/v1/albums/62yzkUYnhehn1cMlRHpegF',
#      'id': '62yzkUYnhehn1cMlRHpegF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a3c835234e54cda9cf4951bc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a3c835234e54cda9cf4951bc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a3c835234e54cda9cf4951bc',
#        'width': 64}],
#      'name': 'Mnemosyne',
#      'release_date': '2015-09-04',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:62yzkUYnhehn1cMlRHpegF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5467S01XgF4JNYDS5eynEZ'},
#       'href': 'https://api.spotify.com/v1/artists/5467S01XgF4JNYDS5eynEZ',
#       'id': '5467S01XgF4JNYDS5eynEZ',
#       'name': 'Lumisokea',
#       'type': 'artist',
#       'uri': 'spotify:artist:5467S01XgF4JNYDS5eynEZ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 303198,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBHLW1501726'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6qK0apPspdUTGwUERX6kxb'},
#     'href': 'https://api.spotify.com/v1/tracks/6qK0apPspdUTGwUERX6kxb',
#     'id': '6qK0apPspdUTGwUERX6kxb',
#     'is_local': False,
#     'name': 'Abri',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/35b32e0afea15fe120c76a66c36d1d568dbd7ba0?cid=63594c9b2f99411a8cbd18df04851fc4',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:6qK0apPspdUTGwUERX6kxb'}},
#   {'added_at': '2019-08-29T00:02:16Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5467S01XgF4JNYDS5eynEZ'},
#        'href': 'https://api.spotify.com/v1/artists/5467S01XgF4JNYDS5eynEZ',
#        'id': '5467S01XgF4JNYDS5eynEZ',
#        'name': 'Lumisokea',
#        'type': 'artist',
#        'uri': 'spotify:artist:5467S01XgF4JNYDS5eynEZ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1KkkP1T610fCneNHJehUr9'},
#      'href': 'https://api.spotify.com/v1/albums/1KkkP1T610fCneNHJehUr9',
#      'id': '1KkkP1T610fCneNHJehUr9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d17b1117000eca965c2fb3ac',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d17b1117000eca965c2fb3ac',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d17b1117000eca965c2fb3ac',
#        'width': 64}],
#      'name': 'Transmissions From Revarsavr',
#      'release_date': '2016-03-04',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:1KkkP1T610fCneNHJehUr9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5467S01XgF4JNYDS5eynEZ'},
#       'href': 'https://api.spotify.com/v1/artists/5467S01XgF4JNYDS5eynEZ',
#       'id': '5467S01XgF4JNYDS5eynEZ',
#       'name': 'Lumisokea',
#       'type': 'artist',
#       'uri': 'spotify:artist:5467S01XgF4JNYDS5eynEZ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 435313,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA2B1600143'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1tRjY29xhTYP6QJOO9v7lg'},
#     'href': 'https://api.spotify.com/v1/tracks/1tRjY29xhTYP6QJOO9v7lg',
#     'id': '1tRjY29xhTYP6QJOO9v7lg',
#     'is_local': False,
#     'name': 'Nanissáanah',
#     'popularity': 1,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f1353deb9668b45b9b092dbd414704de38a96ac6?cid=63594c9b2f99411a8cbd18df04851fc4',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:1tRjY29xhTYP6QJOO9v7lg'}},
#   {'added_at': '2019-08-23T23:50:42Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ifvnt1HhJ0b1QwOxLAu2s'},
#        'href': 'https://api.spotify.com/v1/artists/7Ifvnt1HhJ0b1QwOxLAu2s',
#        'id': '7Ifvnt1HhJ0b1QwOxLAu2s',
#        'name': 'Tzusing',
#        'type': 'artist',
#        'uri': 'spotify:artist:7Ifvnt1HhJ0b1QwOxLAu2s'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/57z5w3F98kxoAjSrSK4oNs'},
#      'href': 'https://api.spotify.com/v1/albums/57z5w3F98kxoAjSrSK4oNs',
#      'id': '57z5w3F98kxoAjSrSK4oNs',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273daba994204a3b7c24d0851d0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02daba994204a3b7c24d0851d0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851daba994204a3b7c24d0851d0',
#        'width': 64}],
#      'name': '東方不敗',
#      'release_date': '2017-05-19',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:57z5w3F98kxoAjSrSK4oNs'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ifvnt1HhJ0b1QwOxLAu2s'},
#       'href': 'https://api.spotify.com/v1/artists/7Ifvnt1HhJ0b1QwOxLAu2s',
#       'id': '7Ifvnt1HhJ0b1QwOxLAu2s',
#       'name': 'Tzusing',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Ifvnt1HhJ0b1QwOxLAu2s'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 293662,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEMM41701206'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3V1oeP60i7Er7QbwzQTYdO'},
#     'href': 'https://api.spotify.com/v1/tracks/3V1oeP60i7Er7QbwzQTYdO',
#     'id': '3V1oeP60i7Er7QbwzQTYdO',
#     'is_local': False,
#     'name': 'King of Hosts',
#     'popularity': 31,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9cc750491bafe5446a40aeab29d73ac0daab9138?cid=63594c9b2f99411a8cbd18df04851fc4',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:3V1oeP60i7Er7QbwzQTYdO'}},
#   {'added_at': '2019-08-23T23:46:59Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6B9SjvZNSQZkeJDH17oBSO'},
#        'href': 'https://api.spotify.com/v1/artists/6B9SjvZNSQZkeJDH17oBSO',
#        'id': '6B9SjvZNSQZkeJDH17oBSO',
#        'name': 'Current Value',
#        'type': 'artist',
#        'uri': 'spotify:artist:6B9SjvZNSQZkeJDH17oBSO'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0F8vwdYqpcDVU5nvcwefEy'},
#      'href': 'https://api.spotify.com/v1/albums/0F8vwdYqpcDVU5nvcwefEy',
#      'id': '0F8vwdYqpcDVU5nvcwefEy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/eb156af02a0fb6f25d17ddd4d35026ef31bf3823',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/f784b78ffc288bba00633c869a0471cac488edba',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/8704ad6b9942f5e616e10b8f1ec49bf5ad4aabbc',
#        'width': 64}],
#      'name': 'Tremor / Maintainer',
#      'release_date': '2015-02-02',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:0F8vwdYqpcDVU5nvcwefEy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6B9SjvZNSQZkeJDH17oBSO'},
#       'href': 'https://api.spotify.com/v1/artists/6B9SjvZNSQZkeJDH17oBSO',
#       'id': '6B9SjvZNSQZkeJDH17oBSO',
#       'name': 'Current Value',
#       'type': 'artist',
#       'uri': 'spotify:artist:6B9SjvZNSQZkeJDH17oBSO'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 326057,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLCK41500156'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0zmHKnEvizzz9AXFyBd3yK'},
#     'href': 'https://api.spotify.com/v1/tracks/0zmHKnEvizzz9AXFyBd3yK',
#     'id': '0zmHKnEvizzz9AXFyBd3yK',
#     'is_local': False,
#     'name': 'Tremor - Original Mix',
#     'popularity': 11,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3087d03a757053be0bcfb97b83135d9bcc6e51d8?cid=63594c9b2f99411a8cbd18df04851fc4',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0zmHKnEvizzz9AXFyBd3yK'}},
#   {'added_at': '2019-08-23T23:24:17Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ifvnt1HhJ0b1QwOxLAu2s'},
#        'href': 'https://api.spotify.com/v1/artists/7Ifvnt1HhJ0b1QwOxLAu2s',
#        'id': '7Ifvnt1HhJ0b1QwOxLAu2s',
#        'name': 'Tzusing',
#        'type': 'artist',
#        'uri': 'spotify:artist:7Ifvnt1HhJ0b1QwOxLAu2s'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/57z5w3F98kxoAjSrSK4oNs'},
#      'href': 'https://api.spotify.com/v1/albums/57z5w3F98kxoAjSrSK4oNs',
#      'id': '57z5w3F98kxoAjSrSK4oNs',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273daba994204a3b7c24d0851d0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02daba994204a3b7c24d0851d0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851daba994204a3b7c24d0851d0',
#        'width': 64}],
#      'name': '東方不敗',
#      'release_date': '2017-05-19',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:57z5w3F98kxoAjSrSK4oNs'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ifvnt1HhJ0b1QwOxLAu2s'},
#       'href': 'https://api.spotify.com/v1/artists/7Ifvnt1HhJ0b1QwOxLAu2s',
#       'id': '7Ifvnt1HhJ0b1QwOxLAu2s',
#       'name': 'Tzusing',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Ifvnt1HhJ0b1QwOxLAu2s'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 311541,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEMM41701203'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7A1d0qBQL2IiDhrDrhUqE8'},
#     'href': 'https://api.spotify.com/v1/tracks/7A1d0qBQL2IiDhrDrhUqE8',
#     'id': '7A1d0qBQL2IiDhrDrhUqE8',
#     'is_local': False,
#     'name': '日出東方 唯我不敗',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ea6d68c2927f0e3338a0087670d898070f7ebce3?cid=63594c9b2f99411a8cbd18df04851fc4',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7A1d0qBQL2IiDhrDrhUqE8'}},
#   {'added_at': '2019-08-23T23:16:32Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6B9SjvZNSQZkeJDH17oBSO'},
#        'href': 'https://api.spotify.com/v1/artists/6B9SjvZNSQZkeJDH17oBSO',
#        'id': '6B9SjvZNSQZkeJDH17oBSO',
#        'name': 'Current Value',
#        'type': 'artist',
#        'uri': 'spotify:artist:6B9SjvZNSQZkeJDH17oBSO'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0LeD490ExO5PuAL6r1sJUQ'},
#      'href': 'https://api.spotify.com/v1/albums/0LeD490ExO5PuAL6r1sJUQ',
#      'id': '0LeD490ExO5PuAL6r1sJUQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739980fb5255d6bba368dcc8f5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029980fb5255d6bba368dcc8f5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519980fb5255d6bba368dcc8f5',
#        'width': 64}],
#      'name': 'Deadly Toys',
#      'release_date': '2017-12-21',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:0LeD490ExO5PuAL6r1sJUQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6B9SjvZNSQZkeJDH17oBSO'},
#       'href': 'https://api.spotify.com/v1/artists/6B9SjvZNSQZkeJDH17oBSO',
#       'id': '6B9SjvZNSQZkeJDH17oBSO',
#       'name': 'Current Value',
#       'type': 'artist',
#       'uri': 'spotify:artist:6B9SjvZNSQZkeJDH17oBSO'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1lOWswYtz0YUS3CJwwhbcK'},
#       'href': 'https://api.spotify.com/v1/artists/1lOWswYtz0YUS3CJwwhbcK',
# ...
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1T1s8CqukiWl0Kx77vmIBh'},
#      'href': 'https://api.spotify.com/v1/albums/1T1s8CqukiWl0Kx77vmIBh',
#      'id': '1T1s8CqukiWl0Kx77vmIBh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e9badbd039195d88db3c0028',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e9badbd039195d88db3c0028',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e9badbd039195d88db3c0028',
#        'width': 64}],
#      'name': 'Scorpio',
#      'release_date': '2019-07-25',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:1T1s8CqukiWl0Kx77vmIBh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/35dxfY1wywqVRUEaVuMm13'},
#       'href': 'https://api.spotify.com/v1/artists/35dxfY1wywqVRUEaVuMm13',
#       'id': '35dxfY1wywqVRUEaVuMm13',
#       'name': 'Bou',
#       'type': 'artist',
#       'uri': 'spotify:artist:35dxfY1wywqVRUEaVuMm13'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1OeYjH80o59axC1PYRV97m'},
#       'href': 'https://api.spotify.com/v1/artists/1OeYjH80o59axC1PYRV97m',
#       'id': '1OeYjH80o59axC1PYRV97m',
#       'name': 'Serum',
#       'type': 'artist',
#       'uri': 'spotify:artist:1OeYjH80o59axC1PYRV97m'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 223542,
#     'explicit': False,
#     'external_ids': {'isrc': 'UKK761920003'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3E940gpOthnGBcxuWkp8UY'},
#     'href': 'https://api.spotify.com/v1/tracks/3E940gpOthnGBcxuWkp8UY',
#     'id': '3E940gpOthnGBcxuWkp8UY',
#     'is_local': False,
#     'name': 'Superstar',
#     'popularity': 29,
#     'preview_url': 'https://p.scdn.co/mp3-preview/04de0be3de02085b545b4c9f011bdaaff7ebe4bc?cid=63594c9b2f99411a8cbd18df04851fc4',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3E940gpOthnGBcxuWkp8UY'}},
#   {'added_at': '2019-08-22T14:46:13Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/35dxfY1wywqVRUEaVuMm13'},
#        'href': 'https://api.spotify.com/v1/artists/35dxfY1wywqVRUEaVuMm13',
#        'id': '35dxfY1wywqVRUEaVuMm13',
#        'name': 'Bou',
#        'type': 'artist',
#        'uri': 'spotify:artist:35dxfY1wywqVRUEaVuMm13'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4LqFJ98PEA7gIrRtviMUmb'},
#        'href': 'https://api.spotify.com/v1/artists/4LqFJ98PEA7gIrRtviMUmb',
#        'id': '4LqFJ98PEA7gIrRtviMUmb',
#        'name': 'Trigga',
#        'type': 'artist',
#        'uri': 'spotify:artist:4LqFJ98PEA7gIrRtviMUmb'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1OeYjH80o59axC1PYRV97m'},
#        'href': 'https://api.spotify.com/v1/artists/1OeYjH80o59axC1PYRV97m',
#        'id': '1OeYjH80o59axC1PYRV97m',
#        'name': 'Serum',
#        'type': 'artist',
#        'uri': 'spotify:artist:1OeYjH80o59axC1PYRV97m'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1T1s8CqukiWl0Kx77vmIBh'},
#      'href': 'https://api.spotify.com/v1/albums/1T1s8CqukiWl0Kx77vmIBh',
#      'id': '1T1s8CqukiWl0Kx77vmIBh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e9badbd039195d88db3c0028',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e9badbd039195d88db3c0028',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e9badbd039195d88db3c0028',
#        'width': 64}],
#      'name': 'Scorpio',
#      'release_date': '2019-07-25',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:1T1s8CqukiWl0Kx77vmIBh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/35dxfY1wywqVRUEaVuMm13'},
#       'href': 'https://api.spotify.com/v1/artists/35dxfY1wywqVRUEaVuMm13',
#       'id': '35dxfY1wywqVRUEaVuMm13',
#       'name': 'Bou',
#       'type': 'artist',
#       'uri': 'spotify:artist:35dxfY1wywqVRUEaVuMm13'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4LqFJ98PEA7gIrRtviMUmb'},
#       'href': 'https://api.spotify.com/v1/artists/4LqFJ98PEA7gIrRtviMUmb',
#       'id': '4LqFJ98PEA7gIrRtviMUmb',
#       'name': 'Trigga',
#       'type': 'artist',
#       'uri': 'spotify:artist:4LqFJ98PEA7gIrRtviMUmb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 269188,
#     'explicit': False,
#     'external_ids': {'isrc': 'UKK761920002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7wj4JxjG3n0Tr9ZNUJCNcI'},
#     'href': 'https://api.spotify.com/v1/tracks/7wj4JxjG3n0Tr9ZNUJCNcI',
#     'id': '7wj4JxjG3n0Tr9ZNUJCNcI',
#     'is_local': False,
#     'name': 'Veteran',
#     'popularity': 44,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ec20ddc6479a591b5d2696a76762bfd4aad7268a?cid=63594c9b2f99411a8cbd18df04851fc4',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7wj4JxjG3n0Tr9ZNUJCNcI'}},
#   {'added_at': '2019-08-22T14:43:37Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4a95izyFgvXS2JYqL8rANq'},
#        'href': 'https://api.spotify.com/v1/artists/4a95izyFgvXS2JYqL8rANq',
#        'id': '4a95izyFgvXS2JYqL8rANq',
#        'name': 'SHOTTY HORROH',
#        'type': 'artist',
#        'uri': 'spotify:artist:4a95izyFgvXS2JYqL8rANq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6MbCh4l8X0Jba7QRqgnchY'},
#      'href': 'https://api.spotify.com/v1/albums/6MbCh4l8X0Jba7QRqgnchY',
#      'id': '6MbCh4l8X0Jba7QRqgnchY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a6763c22fa7de4da4e6346d0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a6763c22fa7de4da4e6346d0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a6763c22fa7de4da4e6346d0',
#        'width': 64}],
#      'name': 'Salt of the Earth',
#      'release_date': '2018-10-12',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:6MbCh4l8X0Jba7QRqgnchY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4a95izyFgvXS2JYqL8rANq'},
#       'href': 'https://api.spotify.com/v1/artists/4a95izyFgvXS2JYqL8rANq',
#       'id': '4a95izyFgvXS2JYqL8rANq',
#       'name': 'SHOTTY HORROH',
#       'type': 'artist',
#       'uri': 'spotify:artist:4a95izyFgvXS2JYqL8rANq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 247466,
#     'explicit': True,
#     'external_ids': {'isrc': 'CADDJ1700010'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0MOjnIQQZASy0Yoy7oALfi'},
#     'href': 'https://api.spotify.com/v1/tracks/0MOjnIQQZASy0Yoy7oALfi',
#     'id': '0MOjnIQQZASy0Yoy7oALfi',
#     'is_local': False,
#     'name': 'Shudehill',
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b2bf27102088f5d46611b0334721bb8ee2fd9a61?cid=63594c9b2f99411a8cbd18df04851fc4',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:0MOjnIQQZASy0Yoy7oALfi'}},
#   {'added_at': '2019-08-22T14:35:32Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7za6M9P94wuMsOVCHopTsI'},
#        'href': 'https://api.spotify.com/v1/artists/7za6M9P94wuMsOVCHopTsI',
#        'id': '7za6M9P94wuMsOVCHopTsI',
#        'name': 'IAMDDB',
#        'type': 'artist',
#        'uri': 'spotify:artist:7za6M9P94wuMsOVCHopTsI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5fABa5up9Eit0AP1juW4Qm'},
#      'href': 'https://api.spotify.com/v1/albums/5fABa5up9Eit0AP1juW4Qm',
#      'id': '5fABa5up9Eit0AP1juW4Qm',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735d078b119272fb1f35cec33a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025d078b119272fb1f35cec33a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515d078b119272fb1f35cec33a',
#        'width': 64}],
#      'name': 'Hoodrich Vol. 3',
#      'release_date': '2017-09-01',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:5fABa5up9Eit0AP1juW4Qm'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7za6M9P94wuMsOVCHopTsI'},
#       'href': 'https://api.spotify.com/v1/artists/7za6M9P94wuMsOVCHopTsI',
#       'id': '7za6M9P94wuMsOVCHopTsI',
#       'name': 'IAMDDB',
#       'type': 'artist',
#       'uri': 'spotify:artist:7za6M9P94wuMsOVCHopTsI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 146615,
#     'explicit': True,
#     'external_ids': {'isrc': 'QM6P41722612'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2STP1Ow0iAeiSglnQmhWnP'},
#     'href': 'https://api.spotify.com/v1/tracks/2STP1Ow0iAeiSglnQmhWnP',
#     'id': '2STP1Ow0iAeiSglnQmhWnP',
#     'is_local': False,
#     'name': 'Conjouring',
#     'popularity': 39,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f63d3657150b63da41fd1b7b359134f77209eae0?cid=63594c9b2f99411a8cbd18df04851fc4',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2STP1Ow0iAeiSglnQmhWnP'}}],
#  'limit': 20,
#  'next': 'https://api.spotify.com/v1/me/tracks?offset=20&limit=20',
#  'offset': 0,
#  'previous': None,
#  'total': 258}

# %%
# results = sp.search()

# q=artist%3Aqueen%20track%3Awe%20will%20rock%20you

# name = "Queen We Will Rock You"
artist = "Queen"
track = "We Will Rock You"
# query = f'q=artist:{artist}%20track:{track}&type=album'
results = sp.search(q='artist:' + artist + ' ' + 'track:' + track, type='track')
# results = sp.search(q='artist:' + name, type='track')
# results = sp.search(q=name, type='track')
results
# items = results['artists']['items']
# if len(items) > 0:
#     artist = items[0]
#     print(artist['name'], artist['images'][0]['url'])

# %%
# query=artist%3Aqueen+track%3Awe+will+rock+you&type=track&offset=0&limit=20"

# %%
results["tracks"]["items"][0]["id"]
# Out:
# '54flyrjcdnQdco7300avMJ'

# %%
for k,v in sp.audio_features('54flyrjcdnQdco7300avMJ')[0].items():
    print(k,v)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     118         try:
# --> 119             r.raise_for_status()
#     120         except:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/audio-features/?ids=54flyrjcdnQdco7300avMJ
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-110-71a117a3e67a> in <module>
# ----> 1 for k,v in sp.audio_features('54flyrjcdnQdco7300avMJ')[0].items():
#       2     print(k,v)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/spotipy/client.py in audio_features(self, tracks)
#     824         if isinstance(tracks, str):
#     825             trackid = self._get_id('track', tracks)
# --> 826             results = self._get('audio-features/?ids=' + trackid)
#     827         else:
#     828             tlist = [self._get_id('track', t) for t in tracks]
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     144         while retries > 0:
#     145             try:
# --> 146                 return self._internal_call('GET', url, payload, kwargs)
#     147             except SpotifyException as e:
#     148                 retries -= 1
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     122                 raise SpotifyException(r.status_code,
#     123                     -1, '%s:\n %s' % (r.url, r.json()['error']['message']),
# --> 124                     headers=r.headers)
#     125             else:
#     126                 raise SpotifyException(r.status_code,
#
# SpotifyException: http status: 401, code:-1 - https://api.spotify.com/v1/audio-features/?ids=54flyrjcdnQdco7300avMJ:
#  The access token expired

# %%
import pandas as pd

song_list = pd.read_pickle("./song_list.pkl")

# %%
song_list.head()
# Out:
#                     0                   1                 2                  3
# 0  TRMMMYQ128F932D901  SOQMMHC12AB0180CB8  Faster Pussy cat       Silent Night
# 1  TRMMMKD128F425225D  SOVFVAK12A8C1350D9  Karkkiautomaatti        Tanssi vaan
# 2  TRMMMRX128F93187D9  SOGTUKN12AB017F4F1    Hudson Mohawke  No One Could Ever
# 3  TRMMMCH128F425532C  SOBNYVR12A8C13558C       Yerba Brava      Si Vos Querés
# 4  TRMMMWA128F426B589  SOHSBXH12A8C13B0DF        Der Mystic   Tangle Of Aspens

# %%
song_list = song_list.drop([0,1], axis=1)

# %%
song_list.head()
# Out:
#                   2                  3
# 0  Faster Pussy cat       Silent Night
# 1  Karkkiautomaatti        Tanssi vaan
# 2    Hudson Mohawke  No One Could Ever
# 3       Yerba Brava      Si Vos Querés
# 4        Der Mystic   Tangle Of Aspens

# %%
{'danceability': 0.693,
 'energy': 0.497,
 'key': 2,
 'loudness': -7.316,
 'mode': 1,
 'speechiness': 0.119,
 'acousticness': 0.679,
 'instrumentalness': 0,
 'liveness': 0.258,
 'valence': 0.473,
 'tempo': 81.308,
 'type': 'audio_features',
 'id': '54flyrjcdnQdco7300avMJ',
 'uri': 'spotify:track:54flyrjcdnQdco7300avMJ',
 'track_href': 'https://api.spotify.com/v1/tracks/54flyrjcdnQdco7300avMJ',
 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/54flyrjcdnQdco7300avMJ',
 'duration_ms': 122067,
 'time_signature': 4}
