# %%
import pandas as pd
import sqlite3
import pickle
import numpy as np

# %%
con = sqlite3.connect("song_list12.db")
df = pd.read_sql_query("SELECT * from songs", con)
con.close()
df = df.drop(['level_0'], axis=1)

# %%
df.head(1)
# Out:
#    index                  songid popularity  acousticness            artist  \
# 0      0  5PS5dpaLogPzYU9hWiWyZb          0        0.0013  Karkkiautomaatti
#
#    danceability  duration_ms  energy  instrumentalness  key  ...  loudness  \
# 0         0.487     157307.0   0.678            0.0551  9.0  ...     -7.78
#
#    mode  speechiness   tempo  time_signature        track valence  \
# 0   1.0       0.0495  149.94             4.0  Tanssi vaan    0.87
#
#                             genres                genres_stripped availability
# 0  ['finnish indie', 'suomi rock']  'finnish indie', 'suomi rock'          1.0
#
# [1 rows x 21 columns]

# %%
workdf = df
workdf.shape
# Out:
# (574018, 21)

# %%
is_available =  workdf['availability']==1.0
workdf_available = workdf[is_available]
workdf_available.shape
# Out:
# (555443, 21)

# %%
workdf_available.head()
# Out:
#    index                  songid popularity  acousticness            artist  \
# 0      0  5PS5dpaLogPzYU9hWiWyZb          0      0.001300  Karkkiautomaatti
# 1      1  41RpZW2lxAdnqDd2nMBzLQ         15      0.000045    Hudson Mohawke
# 2      2  3GsS8jzoixpCnp4jDWCEvb         17      0.002760        Kris Kross
# 3      3  0kq75szR7uDEYrZkT2c4Ry         21      0.348000     Jorge Negrete
# 4      4  2HyFpkX9J7vv3OZNDaraHZ          1      0.340000         Tiger Lou
#
#    danceability  duration_ms  energy  instrumentalness   key  ...  loudness  \
# 0         0.487     157307.0   0.678          0.055100   9.0  ...    -7.780
# 1         0.662     138960.0   0.823          0.952000   4.0  ...    -1.711
# 2         0.859     221200.0   0.741          0.000000  11.0  ...   -12.329
# 3         0.361     173573.0   0.483          0.000003   7.0  ...    -6.875
# 4         0.533     318467.0   0.302          0.179000  10.0  ...   -10.308
#
# ...

# %%
workdf_available = workdf_available.drop(['genres_stripped', 'availability', 'index'], axis=1)

# %%
workdf_available.head()
# Out:
#                    songid popularity  acousticness            artist  \
# 0  5PS5dpaLogPzYU9hWiWyZb          0      0.001300  Karkkiautomaatti
# 1  41RpZW2lxAdnqDd2nMBzLQ         15      0.000045    Hudson Mohawke
# 2  3GsS8jzoixpCnp4jDWCEvb         17      0.002760        Kris Kross
# 3  0kq75szR7uDEYrZkT2c4Ry         21      0.348000     Jorge Negrete
# 4  2HyFpkX9J7vv3OZNDaraHZ          1      0.340000         Tiger Lou
#
#    danceability  duration_ms  energy  instrumentalness   key  liveness  \
# 0         0.487     157307.0   0.678          0.055100   9.0    0.0846
# 1         0.662     138960.0   0.823          0.952000   4.0    0.3430
# 2         0.859     221200.0   0.741          0.000000  11.0    0.3250
# 3         0.361     173573.0   0.483          0.000003   7.0    0.1770
# 4         0.533     318467.0   0.302          0.179000  10.0    0.1110
#
#    loudness  mode  speechiness    tempo  time_signature               track  \
# ...

# %%
workdf_available.reset_index(inplace=True)

# %%
workdf_available.head()
# Out:
#    index                  songid popularity  acousticness            artist  \
# 0      0  5PS5dpaLogPzYU9hWiWyZb          0      0.001300  Karkkiautomaatti
# 1      1  41RpZW2lxAdnqDd2nMBzLQ         15      0.000045    Hudson Mohawke
# 2      2  3GsS8jzoixpCnp4jDWCEvb         17      0.002760        Kris Kross
# 3      3  0kq75szR7uDEYrZkT2c4Ry         21      0.348000     Jorge Negrete
# 4      4  2HyFpkX9J7vv3OZNDaraHZ          1      0.340000         Tiger Lou
#
#    danceability  duration_ms  energy  instrumentalness   key  liveness  \
# 0         0.487     157307.0   0.678          0.055100   9.0    0.0846
# 1         0.662     138960.0   0.823          0.952000   4.0    0.3430
# 2         0.859     221200.0   0.741          0.000000  11.0    0.3250
# 3         0.361     173573.0   0.483          0.000003   7.0    0.1770
# 4         0.533     318467.0   0.302          0.179000  10.0    0.1110
#
#    loudness  mode  speechiness    tempo  time_signature               track  \
# ...

# %%
pickle.dump( workdf_available, open( "song_list_v6.pkl", "wb" ) )
