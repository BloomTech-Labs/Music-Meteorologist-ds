# %%
import pandas as pd
import sqlite3

# %%
con = sqlite3.connect("./for_backend/song_list4.sqlite3")
df_1_of_3 = pd.read_sql_query("SELECT * from File", con)

# %%
df_2_of_3 = pd.read_csv("./for_backend/song_list5.csv")

# %%
con = sqlite3.connect("./for_backend/song_list6.sqlite3")
df_3_of_3 = pd.read_sql_query("SELECT * from File", con)

# %%
df_1_of_3.head()
# Out:
#                    songid              artist              track  \
# 0  5PS5dpaLogPzYU9hWiWyZb    Karkkiautomaatti        Tanssi vaan
# 1  41RpZW2lxAdnqDd2nMBzLQ      Hudson Mohawke  No One Could Ever
# 2  2poHURuOfVNbzZdivAwtOH          Der Mystic   Tangle Of Aspens
# 3  1jg9hZnReygpBvV2axGuPy  Sasha / Turbulence   We Have Got Love
# 4  3GsS8jzoixpCnp4jDWCEvb          Kris Kross  2 Da Beat Ch'yall
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.487   0.678   9.0    -7.780   1.0       0.0495      0.001300
# 1         0.662   0.823   4.0    -1.711   0.0       0.0662      0.000045
# 2         0.430   0.960   5.0    -7.741   0.0       0.0431      0.000725
# 3         0.663   0.677   3.0    -4.117   0.0       0.0755      0.245000
# 4         0.859   0.741  11.0   -12.329   0.0       0.2710      0.002760
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# ...

# %%
df_1_of_3.shape
# Out:
# (44572, 16)

# %%
df_2_of_3.shape
# Out:
# (49985, 16)

# %%
df_3_of_3.shape
# Out:
# (120826, 16)

# %%
frames = [df_1_of_3, df_2_of_3, df_3_of_3]

df = pd.concat(frames)

# %%
df.shape
# Out:
# (215383, 16)

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#    index                  songid              artist              track  \
# 0      0  5PS5dpaLogPzYU9hWiWyZb    Karkkiautomaatti        Tanssi vaan
# 1      1  41RpZW2lxAdnqDd2nMBzLQ      Hudson Mohawke  No One Could Ever
# 2      2  2poHURuOfVNbzZdivAwtOH          Der Mystic   Tangle Of Aspens
# 3      3  1jg9hZnReygpBvV2axGuPy  Sasha / Turbulence   We Have Got Love
# 4      4  3GsS8jzoixpCnp4jDWCEvb          Kris Kross  2 Da Beat Ch'yall
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.487   0.678   9.0    -7.780   1.0       0.0495      0.001300
# 1         0.662   0.823   4.0    -1.711   0.0       0.0662      0.000045
# 2         0.430   0.960   5.0    -7.741   0.0       0.0431      0.000725
# 3         0.663   0.677   3.0    -4.117   0.0       0.0755      0.245000
# 4         0.859   0.741  11.0   -12.329   0.0       0.2710      0.002760
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# ...

# %%
df = df.rename(columns={"index": "id"})

# %%
df.head()
# Out:
#    id                  songid              artist              track  \
# 0   0  5PS5dpaLogPzYU9hWiWyZb    Karkkiautomaatti        Tanssi vaan
# 1   1  41RpZW2lxAdnqDd2nMBzLQ      Hudson Mohawke  No One Could Ever
# 2   2  2poHURuOfVNbzZdivAwtOH          Der Mystic   Tangle Of Aspens
# 3   3  1jg9hZnReygpBvV2axGuPy  Sasha / Turbulence   We Have Got Love
# 4   4  3GsS8jzoixpCnp4jDWCEvb          Kris Kross  2 Da Beat Ch'yall
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.487   0.678   9.0    -7.780   1.0       0.0495      0.001300
# 1         0.662   0.823   4.0    -1.711   0.0       0.0662      0.000045
# 2         0.430   0.960   5.0    -7.741   0.0       0.0431      0.000725
# 3         0.663   0.677   3.0    -4.117   0.0       0.0755      0.245000
# 4         0.859   0.741  11.0   -12.329   0.0       0.2710      0.002760
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# ...

# %%
df.to_pickle("./data/df_v2.pkl")

# %%
# df.to_json(orient='records')

df.to_json("./data/db_v2.json",orient="records")
