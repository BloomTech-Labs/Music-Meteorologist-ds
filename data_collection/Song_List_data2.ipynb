# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/user/Documents/GitHub/Datasets/Spotify/master_data/track_features.csv")

# %%
colnames=["trackId","songId","artist","track"]

df2 = pd.read_csv("./data/million_songs_dataset.txt",sep="<SEP>",names=colnames,header=None)
# Out:
# /Users/user/.local/share/virtualenvs/data_collection-PY2mH6bz/lib/python3.7/site-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df2.head()
# Out:
#               trackId              songId            artist              track
# 0  TRMMMYQ128F932D901  SOQMMHC12AB0180CB8  Faster Pussy cat       Silent Night
# 1  TRMMMKD128F425225D  SOVFVAK12A8C1350D9  Karkkiautomaatti        Tanssi vaan
# 2  TRMMMRX128F93187D9  SOGTUKN12AB017F4F1    Hudson Mohawke  No One Could Ever
# 3  TRMMMCH128F425532C  SOBNYVR12A8C13558C       Yerba Brava      Si Vos Querés
# 4  TRMMMWA128F426B589  SOHSBXH12A8C13B0DF        Der Mystic   Tangle Of Aspens

# %%
df2.describe()
# Out:
#                    trackId              songId           artist   track
# count              1000000             1000000          1000000  999985
# unique             1000000              999056            72665  702000
# top     TRNGNRZ12903CCFC2E  SOFQIZF12A67ADE730  Michael Jackson   Intro
# freq                     1                   3              194    1511

# %%
df2.head()
# Out:
#               trackId              songId            artist              track
# 0  TRMMMYQ128F932D901  SOQMMHC12AB0180CB8  Faster Pussy cat       Silent Night
# 1  TRMMMKD128F425225D  SOVFVAK12A8C1350D9  Karkkiautomaatti        Tanssi vaan
# 2  TRMMMRX128F93187D9  SOGTUKN12AB017F4F1    Hudson Mohawke  No One Could Ever
# 3  TRMMMCH128F425532C  SOBNYVR12A8C13558C       Yerba Brava      Si Vos Querés
# 4  TRMMMWA128F426B589  SOHSBXH12A8C13B0DF        Der Mystic   Tangle Of Aspens

# %%
df["track_id"][:10]
# Out:
# 0    t_2e8f4b71-8a0b-4b9c-b7d8-fb5208e87f9f
# 1    t_dae2ec0e-ec7b-4b3e-b60c-4a884d0eccb0
# 2    t_cf0164dd-1531-4399-bfa6-dec19cd1fedc
# 3    t_0f90acc7-d5c5-4e53-901d-55610fbd090c
# 4    t_36b9ad02-095a-443d-a697-6c7285d9410a
# 5    t_cbf7084a-0ab7-40b2-8e47-a010580e8d15
# 6    t_2ee16606-ba70-419f-a437-7c6ee2b8ec26
# 7    t_3e80fb67-dc0b-4a97-aff8-88d82f452f9d
# 8    t_f9b9a072-8dae-4816-bfd6-d91fc75a5744
# 9    t_d076e5fa-174c-4614-a1b8-371bd0ea3343
# Name: track_id, dtype: object

# %%
df.describe(include="all")
# Out:
#                                       track_id      duration  release_year  \
# count                                  1853311  1.853311e+06  1.853311e+06
# unique                                 1853311           NaN           NaN
# top     t_74c72aef-f593-445e-8e50-06322788d961           NaN           NaN
# freq                                         1           NaN           NaN
# mean                                       NaN  2.332751e+02  2.009259e+03
# std                                        NaN  1.086198e+02  1.103782e+01
# min                                        NaN  3.000095e+01  1.950000e+03
# 25%                                        NaN  1.768273e+02  2.006000e+03
# 50%                                        NaN  2.178956e+02  2.013000e+03
# 75%                                        NaN  2.671304e+02  2.017000e+03
# max                                        NaN  1.799815e+03  2.018000e+03
#
# ...

# %%
import pyechonest

# %%
# !pwd
# Out:
# /Users/user/Documents/GitHub/Lambda/Data-Science-SSS/data acquisition

# %%
df2.to_pickle("./song_list.pkl")

# %% [markdown]
# # Explore MusicBrainzDB

# %%
musicbrainz = pd.read_csv("/Users/user/Downloads/mbdump/mbdump/track",sep='\t')

# %%
musicbrainz.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6e5049a3120d> in <module>
# ----> 1 musicbrainz.shape
#
# NameError: name 'musicbrainz' is not defined

# %%
musicbrainz.head()

# %%
musicbrainz.describe()

# %%
df = pd.read_csv("./data/song_list5.csv")

# %%
df.head()
# Out:
#                    songid       artist                    track  danceability  \
# 0  5X4Qm0rVLcZeeO4tSDmBg3   Jack Bruce  Running Thro' Our Hands         0.456
# 1  1pNpt53PZPet9dvJN3RKGr   Prefuse 73        Parachute Panador         0.535
# 2  3oxz2oCzAWdPzA6In2zA5u  Pasion Vega   La Gata Bajo La Lluvia         0.294
# 3  05JGVUwt7XJk5FPqH0Wsch   Jonny Lang             Walking Away         0.563
# 4  3xdgCFMTn6ut8fZYxfAuR0         Skye         All the Promises         0.358
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.255  9.0   -15.805   1.0       0.0480       0.94600          0.170000
# 1   0.806  7.0   -10.289   1.0       0.0642       0.00436          0.019100
# 2   0.482  5.0    -6.406   1.0       0.0430       0.46300          0.000000
# 3   0.631  0.0    -5.144   1.0       0.0324       0.06350          0.000008
# 4   0.611  2.0    -9.752   0.0       0.0454       0.51500          0.000468
#
# ...

# %% [markdown]
# # Load Existing Collected Data

# %%
import sqlite3
import pandas as pd

con = sqlite3.connect("./data/song_list4.sqlite3")
df4 = pd.read_sql_query("SELECT * from File", con)

# %%
df4.head()
# Out:
#                    songid              artist              track  \
# 0  5PS5dpaLogPzYU9hWiWyZb    Karkkiautomaatti        Tanssi vaan
# 1  41RpZW2lxAdnqDd2nMBzLQ      Hudson Mohawke  No One Could Ever
# 2  2poHURuOfVNbzZdivAwtOH          Der Mystic   Tangle Of Aspens
# 3  1jg9hZnReygpBvV2axGuPy  Sasha / Turbulence   We Have Got Love
# 4  3GsS8jzoixpCnp4jDWCEvb          Kris Kross  2 Da Beat Ch'yall
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.487   0.678   9.0    -7.780   1.0       0.0495      0.001300
# 1         0.662   0.823   4.0    -1.711   0.0       0.0662      0.000045
# 2         0.430   0.960   5.0    -7.741   0.0       0.0431      0.000725
# 3         0.663   0.677   3.0    -4.117   0.0       0.0755      0.245000
# 4         0.859   0.741  11.0   -12.329   0.0       0.2710      0.002760
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# ...

# %%
df4.shape
# Out:
# (44572, 16)

# %%
df5 = pd.read_csv("./data/song_list5.csv")

# %%
df5.head()
# Out:
#                    songid       artist                    track  danceability  \
# 0  5X4Qm0rVLcZeeO4tSDmBg3   Jack Bruce  Running Thro' Our Hands         0.456
# 1  1pNpt53PZPet9dvJN3RKGr   Prefuse 73        Parachute Panador         0.535
# 2  3oxz2oCzAWdPzA6In2zA5u  Pasion Vega   La Gata Bajo La Lluvia         0.294
# 3  05JGVUwt7XJk5FPqH0Wsch   Jonny Lang             Walking Away         0.563
# 4  3xdgCFMTn6ut8fZYxfAuR0         Skye         All the Promises         0.358
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.255  9.0   -15.805   1.0       0.0480       0.94600          0.170000
# 1   0.806  7.0   -10.289   1.0       0.0642       0.00436          0.019100
# 2   0.482  5.0    -6.406   1.0       0.0430       0.46300          0.000000
# 3   0.631  0.0    -5.144   1.0       0.0324       0.06350          0.000008
# 4   0.611  2.0    -9.752   0.0       0.0454       0.51500          0.000468
#
# ...

# %%
df5.shape
# Out:
# (49985, 16)

# %%
con = sqlite3.connect("./data/song_list6 copy.sqlite3")
df6 = pd.read_sql_query("SELECT * from File", con)

# %%
df6.head()
# Out:
#                    songid         artist                     track  \
# 0  4b5hXQmb0Bs9cXAjMVDl1G  Helen Forrest  I Had The Craziest Dream
# 1  6cG3kY60HMcFqiZN8frkXF  Reel Big Fish  She Has A Girlfriend Now
# 2  0avnjUCLGaEIzdgDU3scpR     Mari Trini          Ni Nada Ni Nadie
# 3  7CKF6UYVCJIBwjf0nqhXY5        Pyrelli        Snailspeech (Skit)
# 4  4Cn3FLEAj3KFeYcIVmfuES            CSS            Beautiful Song
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.248  0.0658   8.0   -18.926   1.0       0.0469       0.96500
# 1         0.713  0.8610   0.0    -5.665   0.0       0.0440       0.08380
# 2         0.454  0.2350   4.0   -12.236   0.0       0.0328       0.60400
# 3         0.818  0.1700   1.0   -10.712   1.0       0.8370       0.84500
# 4         0.612  0.8130  11.0    -4.928   0.0       0.0279       0.00343
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# ...

# %%
df6.shape
# Out:
# (453231, 16)

# %%
con = sqlite3.connect("./data/song_list7.sqlite3")
df7 = pd.read_sql_query("SELECT * from File", con)

# %%
df7.tail()
# Out:
#                         songid          artist                     track  \
# 118738  40PfJGXSPxlHn6PLb9SkJf       Bah Samba            So Many People
# 118739  2QA63aCrxabOQbMZqMxZhW         SKYCLAD         Inequality Street
# 118740  4iSImIN2L3sTkBZTjxc4m0      Loose Shus  Taurus (Keenhouse Remix)
# 118741  5iMMFZLk0Ao2dNwOwOBQHj  Gabriel Le Mar                   Novemba
# 118742  5SJGKyJwfTUWxHX8CMBeK0           Elude                   Faraday
#
#         danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 118738         0.315   0.273   4.0    -8.015   0.0       0.0305      0.914000
# 118739         0.253   0.789   9.0    -4.982   0.0       0.0991      0.000285
# 118740         0.612   0.658   1.0    -6.146   0.0       0.0718      0.010800
# 118741         0.687   0.899  11.0    -8.344   0.0       0.0500      0.000090
# 118742         0.495   0.974  11.0    -8.875   1.0       0.0591      0.000111
#
# ...

# %%
df7.shape
# Out:
# (118743, 16)

# %%
con = sqlite3.connect("./data/songs_with_quotes.sqlite3")
df8 = pd.read_sql_query("SELECT * from File", con)

# %%
df8.shape
# Out:
# (1182, 16)

# %%
df8.head()
# Out:
#                    songid                 artist  \
# 0  6jJ6TetWH7VMvZTdWa5gOx  Willie Big Eyes Smith
# 1  33ZceCdomD90b9EEpHqolK    Charlie Bird Parker
# 2  7BlDqVZOHWbrm45rgKeZOI   Andrew Jr. Boy Jones
# 3  6BDMvjPOmi6GxxDCkhriRw        Michael Jackson
# 4  4vGWyNHyhNS44QXXwxaLRV          Queen Latifah
#
#                                           track  danceability  energy  key  \
# 0                                  Tell Me Mama         0.659   0.731  0.0
# 1                                Now's the Time         0.612   0.262  5.0
# 2                                 I Got A Stick         0.350   0.873  5.0
# 3  Happy (Love Theme From Lady Sings The Blues)         0.370   0.562  9.0
# 4          Big Blonde And Beautiful (Hairspray)         0.609   0.834  0.0
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -6.109   1.0       0.1290        0.6260          0.000508     0.497
# ...

# %%
df9 = pd.read_csv("./data_sandbox/SpotifyAudioFeaturesApril2019.csv")

# %%
def df_update(df):
    df = df.drop(["popularity"],axis=1)
    df = df.rename(columns={"artist_name": "artist", "track_name": "track", "track_id": "songid"})
    return df

df9 = df_update(df9)

# %%
df10 = pd.read_csv("./data_sandbox/SpotifyAudioFeaturesNov2018.csv")

# %%
df10 = df_update(df10)

# %%
df9.shape[0] + df10.shape[0]
# Out:
# 247035

# %%
df10.shape
# Out:
# (116372, 16)

# %%
44572 + 49985 + 453231 + 118743
# Out:
# 666531

# %%
728156 / 247035
# Out:
# 2.947582326390997

# %% [markdown]
# # Concat Only Previously Used CSVs

# %%
df_all_temp = pd.concat([df9,df10])

# %%
df_all_temp.shape
# Out:
# (247035, 16)

# %%
df_all_temp['songid'].nunique()
# Out:
# 130989

# %%
247035 / 130989
# Out:
# 1.8859217186175938

# %%
728156 / 130989
# Out:
# 5.558909526754155

# %% [markdown]
# # Concat All Dataframes

# %%
df_all = pd.concat([df4,df5,df6,df7,df8,df9,df10])
# Out:
# /Users/user/.local/share/virtualenvs/data_collection-PY2mH6bz/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df_all.shape
# Out:
# (914748, 16)

# %%
df_all["songid"].shape
# Out:
# (914748,)

# %%
df_all['songid'].nunique()
# Out:
# 728156

# %%
df_all.drop_duplicates('songid').shape
# Out:
# (728156, 16)

# %%
df_final = df_all.drop_duplicates('songid')

# %%
df_final.shape
# Out:
# (728156, 16)

# %%
df_final.head()
# Out:
#    acousticness              artist  danceability  duration_ms  energy  \
# 0      0.001300    Karkkiautomaatti         0.487     157307.0   0.678
# 1      0.000045      Hudson Mohawke         0.662     138960.0   0.823
# 2      0.000725          Der Mystic         0.430     514290.0   0.960
# 3      0.245000  Sasha / Turbulence         0.663     212413.0   0.677
# 4      0.002760          Kris Kross         0.859     221200.0   0.741
#
#    instrumentalness   key  liveness  loudness  mode                  songid  \
# 0            0.0551   9.0    0.0846    -7.780   1.0  5PS5dpaLogPzYU9hWiWyZb
# 1            0.9520   4.0    0.3430    -1.711   0.0  41RpZW2lxAdnqDd2nMBzLQ
# 2            0.9250   5.0    0.1230    -7.741   0.0  2poHURuOfVNbzZdivAwtOH
# 3            0.0000   3.0    0.3500    -4.117   0.0  1jg9hZnReygpBvV2axGuPy
# 4            0.0000  11.0    0.3250   -12.329   0.0  3GsS8jzoixpCnp4jDWCEvb
#
#    speechiness    tempo  time_signature              track  valence
# ...

# %%
df_final.to_pickle("./final_data/DF_v1.pkl")

# %% [markdown]
# # For Search Lookups

# %%
df_quotes2 = df_quotes.reset_index()

# %%
pd.options.display.max_rows = 40

# %%
df_quotes2.head(40)
# Out:
#     index             trackId              songId  \
# 0       5  TRMMMXN128F42936A5  SOZVAPQ12A8C13B63C
# 1     116  TRMMGQO12903CD4F19  SOHCDDC12AB018B206
# 2     393  TRMMBOJ128F429DAF3  SOKSQVY12A8C142295
# 3     500  TRMMZSA128F4233C55  SOBXHIT12A8C130F59
# 4     757  TRMMPCG128F92D53AF  SOCVTQC12A8C145E01
# 5     980  TRMMEMA128F930DE6B  SOYGIWY12AB017B440
# 6    1009  TRMMEMX12903CE264B  SOBSFJO12AC468A8EB
# 7    1347  TRMMXIY128F4288D0F  SOXOUYX12A8C138F8E
# 8    1418  TRMMKVV12903CAEF8D  SORGZBA12A58A7B5FE
# 9    1466  TRMMYLM128F42AC3E8  SOGMZJL12A8C13D54B
# 10   1579  TRMWWEF128F424ACBB  SOVUQMW12A8C13384C
# 11   1675  TRMWGKM12903CCE78B  SOTLHDK12AB018A405
# 12   1986  TRMWQEK128F4230686  SOOJKFU12A81C223E0
# 13   1992  TRMWQNC128F42A680F  SOQRIAA12A8C13D1F2
# 14   2143  TRMWIMQ12903CB1E7E  SOQUQVX12AB018730E
# 15   2369  TRMWUEU128F425702B  SONPFXA12A8C137CFA
# 16   2604  TRMWSNS128F4289333  SOARTDA12A58A77F34
# 17   2946  TRMWYGE128F92F2743  SOVGUAL12AB017D6E1
# ...

# %%
df_quotes2[df_quotes2["track"].str.contains('Buddy')]
# Out:
#        index             trackId              songId  \
# 1713  400749  TRIIOYL128F935015C  SOEFQNY12A58A7C686
# 4348  998404  TRYKKRI128F424D5DE  SOKEGCI12A8C130FFD
#
#                         artist  \
# 1713               Buddy Holly
# 4348  Eddie "Cleanhead" Vinson
#
#                                                   track
# 1713  Untitled Instrumental (aka: Buddy's Guitar/lis...
# 4348                               If You Were My Buddy

# %%
df_quotes.shape
# Out:
# (4354, 4)

# %%
#run once remainder of db pulled

df2[(df2["artist"].str.contains('"')) | (df2["track"].str.contains('"'))]
# Out:
#                    trackId              songId                    artist  \
# 5       TRMMMXN128F42936A5  SOZVAPQ12A8C13B63C          David Montgomery
# 116     TRMMGQO12903CD4F19  SOHCDDC12AB018B206   Richard "Groove" Holmes
# 393     TRMMBOJ128F429DAF3  SOKSQVY12A8C142295  Damian "Jr. Gong" Marley
# 500     TRMMZSA128F4233C55  SOBXHIT12A8C130F59   Willie "Big Eyes" Smith
# 757     TRMMPCG128F92D53AF  SOCVTQC12A8C145E01              Oingo Boingo
# ...                    ...                 ...                       ...
# 998698  TRYYHMB128F4293033  SOJXZXS12A8C141732             Bang On A Can
# 999149  TRYYAJH128F4270D40  SOHRAIA12A8C135C0C            Claudio Abbado
# 999276  TRYYPKJ128F427102E  SOMMWAS12A8C1355F6            The Weathermen
# 999383  TRYYUVT128F145336D  SODKXGC12A6D4F607B          Daniel Barenboim
# 999747  TRYYOYO128F427D0B2  SOGEQXI12A8C13D919       Alban Berg Quartett
#
#                                                     track
# ...

# %%
df_quotes = df2[(df2["artist"].str.contains('"')) | (df2["track"].str.contains('"'))]

# %%
df_quotes.to_pickle("./data/songs_with_quotes.pkl")

# %%
df3.shape
# Out:
# (933213, 4)

# %%
df5 = pd.read_csv("./song_list5.csv")

# %%
df5.head()
# Out:
#                    songid       artist                    track  danceability  \
# 0  5X4Qm0rVLcZeeO4tSDmBg3   Jack Bruce  Running Thro' Our Hands         0.456
# 1  1pNpt53PZPet9dvJN3RKGr   Prefuse 73        Parachute Panador         0.535
# 2  3oxz2oCzAWdPzA6In2zA5u  Pasion Vega   La Gata Bajo La Lluvia         0.294
# 3  05JGVUwt7XJk5FPqH0Wsch   Jonny Lang             Walking Away         0.563
# 4  3xdgCFMTn6ut8fZYxfAuR0         Skye         All the Promises         0.358
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.255  9.0   -15.805   1.0       0.0480       0.94600          0.170000
# 1   0.806  7.0   -10.289   1.0       0.0642       0.00436          0.019100
# 2   0.482  5.0    -6.406   1.0       0.0430       0.46300          0.000000
# 3   0.631  0.0    -5.144   1.0       0.0324       0.06350          0.000008
# 4   0.611  2.0    -9.752   0.0       0.0454       0.51500          0.000468
#
# ...

# %%
df5.tail()
# Out:
#                        songid           artist          track  danceability  \
# 49980  1K2ca2dSGuhDCe2uqBNCo2            Adeva    I Thank You         0.797
# 49981  0HMQQflKAzVC4ZpeO0a1pm    Kidz Bop Kids     Move Along         0.655
# 49982  5V6bkhWzVJsKchObfqi5oo  The Procussions   Miss January         0.426
# 49983  1zzRJsvY32lHgIRnSWEFx7               U2      The Ocean         0.508
# 49984  6t9dKp7Nf1t4HpYXOdeVNl           Lambda  Hold On Tight         0.689
#
#        energy   key  loudness  mode  speechiness  acousticness  \
# 49980   0.331  10.0   -17.076   0.0       0.0724       0.01850
# 49981   0.706   3.0    -8.143   1.0       0.0577       0.07260
# 49982   0.780  10.0    -6.016   0.0       0.4020       0.00978
# 49983   0.292   3.0   -15.106   0.0       0.0319       0.87500
# 49984   0.765   9.0    -9.246   0.0       0.0332       0.04870
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# ...

# %%
df2[df2["artist"].str.contains("Siegfried & Roy - Lesungen","Jungfrau")]
# Out:
#                    trackId              songId                      artist  \
# 36934   TRMKDCA128F423695B  SOLMRPI12A81C233D1  Siegfried & Roy - Lesungen
# 80878   TRGGJPM128F4236951  SODPQKM12A81C233BB  Siegfried & Roy - Lesungen
# 115035  TRGYYBE128F423695A  SORJZHP12A81C233D0  Siegfried & Roy - Lesungen
# 385739  TRIMUOY128F4236957  SOUISHW12A81C233C8  Siegfried & Roy - Lesungen
# 472059  TRNBELO128F4236955  SOZLDUU12A81C233C4  Siegfried & Roy - Lesungen
# 537452  TRPKUJF128F4236950  SOHUBDQ12A81C233B8  Siegfried & Roy - Lesungen
# 545359  TRTCMHK128F4236952  SOEGBVU12A81C233BC  Siegfried & Roy - Lesungen
# 757674  TRSEYOY128F4236954  SOQKUIJ12A81C233C0  Siegfried & Roy - Lesungen
# 821730  TRDZQMV128F4236956  SOQSMEH12A81C233C6  Siegfried & Roy - Lesungen
# 837587  TRDSYIQ128F4236959  SOAJOPI12A81C233CD  Siegfried & Roy - Lesungen
# 877434  TRODWAP128F4236953  SOEHWTU12A81C233BE  Siegfried & Roy - Lesungen
# ...

# %%
df2[df2["artist"].str.contains("Elude")]
# Out:
#                    trackId              songId artist    track
# 167978  TRCZLRW128F9306A05  SOXKAUK12AB017CC87  Elude  Faraday
# 999998  TRYYYDJ128F9310A21  SOLXGOR12A81C21EB7  Elude  Faraday

# %%
# Out:
#                    trackId              songId                       artist  \
# 821731  TRDZQXN12903CB8928  SOGTZOV12AB018859A                     Lifelike
# 821732  TRDZQYA128F92F4ED2  SOYZAFF12A8C1425D3                       Natali
# 821733  TRDZQYR12903CD6F2A  SOKNFNA12A8C13C561  She's Spanish_ I'm American
# 821734  TRDZQPQ128EF34B677  SOIJCTQ12A6BD5378C                    Dreadzone
# 821735  TRDZQMT128F146D62D  SOWXCCR12CF5F8933E              Yeah Yeah Yeahs
# ...                    ...                 ...                          ...
# 999995  TRYYYUS12903CD2DF0  SOTXAME12AB018F136                 Kiko Navarro
# 999996  TRYYYJO128F426DA37  SOXQYIQ12A8C137FBB                Kuldeep Manak
# 999997  TRYYYMG128F4260ECA  SOHODZI12A8C137BB3               Gabriel Le Mar
# 999998  TRYYYDJ128F9310A21  SOLXGOR12A81C21EB7                        Elude
# 999999  TRYYYVU12903CD01E3  SOWXJXQ12AB0189F43                        Texta
#
#                                       track
# ...

# %%
df7 = df2[821731:]

# %%
df7.to_pickle("./song_list7.pkl")

# %%
1000000 - 821731
# Out:
# 178269
