# %%
from sqlalchemy import create_engine
import pandas as pd
import sqlite3
import numpy as np

# %%
con = sqlite3.connect("song_list_v3_21.db")
# Load the data into a DataFrame
X = pd.read_sql_query("SELECT * from songs", con)
con.close()

# %%
X.head(2)
# Out:
#    level_0  index  acousticness            artist  danceability  duration_ms  \
# 0        0      0      0.001300  Karkkiautomaatti         0.487     157307.0
# 1        1      1      0.000045    Hudson Mohawke         0.662     138960.0
#
#    energy  instrumentalness  key  liveness  ...  mode                  songid  \
# 0   0.678            0.0551  9.0    0.0846  ...   1.0  5PS5dpaLogPzYU9hWiWyZb
# 1   0.823            0.9520  4.0    0.3430  ...   0.0  41RpZW2lxAdnqDd2nMBzLQ
#
#   speechiness    tempo  time_signature              track valence  \
# 0      0.0495  149.940             4.0        Tanssi vaan   0.870
# 1      0.0662  177.745             4.0  No One Could Ever   0.621
#
#                                               genres popularity availability
# 0                    ['finnish indie', 'suomi rock']          0            1
# 1  ['bass music', 'scottish electronic', 'scottis...         15            1
#
# [2 rows x 21 columns]

# %%
X = X.drop('index', axis=1)

# %%
X = X.reset_index()

# %%
X = X.drop('level_0', axis=1)

# %%
X = X.drop('index', axis=1)

# %%
X.availability.value_counts()
# Out:
# 1      574016
# NaN         2
# Name: availability, dtype: int64

# %%
[] == None
# Out:
# False

# %%
X.head(5)
# Out:
#    level_0  acousticness            artist  danceability  duration_ms  energy  \
# 0        0      0.001300  Karkkiautomaatti         0.487     157307.0   0.678
# 1        1      0.000045    Hudson Mohawke         0.662     138960.0   0.823
# 2        2      0.002760        Kris Kross         0.859     221200.0   0.741
# 3        3      0.348000     Jorge Negrete         0.361     173573.0   0.483
# 4        4      0.340000         Tiger Lou         0.533     318467.0   0.302
#
#    instrumentalness   key  liveness  loudness  mode                  songid  \
# 0          0.055100   9.0    0.0846    -7.780   1.0  5PS5dpaLogPzYU9hWiWyZb
# 1          0.952000   4.0    0.3430    -1.711   0.0  41RpZW2lxAdnqDd2nMBzLQ
# 2          0.000000  11.0    0.3250   -12.329   0.0  3GsS8jzoixpCnp4jDWCEvb
# 3          0.000003   7.0    0.1770    -6.875   1.0  0kq75szR7uDEYrZkT2c4Ry
# 4          0.179000  10.0    0.1110   -10.308   1.0  2HyFpkX9J7vv3OZNDaraHZ
#
# ...

# %%
engine = create_engine('sqlite:///song_list_v3.db', echo=False)
X.to_sql('songs', con=engine)
