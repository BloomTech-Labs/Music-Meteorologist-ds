# %% [markdown]
# # Imports

# %%
import spotipy
import spotipy.util as util
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from flask import request
import pandas as pd
import timeit
from pandas.io.json import json_normalize
from flask import jsonify
from joblib import load
import pickle

# %% [markdown]
# # Required Base Func

# %%
def instantiate_sp(token):
    sp = spotipy.Spotify(auth=token)
    return sp

# %%
def get_id(sp):
    results = sp.current_user_saved_tracks()
    song_id = results['items'][0]['track']['id']
    return song_id

# %%
def get_features(song_id,sp):
    results_dict = sp.audio_features(song_id)[0]
    audio_features = {
        "audio_features": {
            key: results_dict[key] for key in results_dict.keys() & {
                'danceability',
                'energy',
                'key',
                'loudness',
                'mode',
                'speechiness',
                'acousticness',
                'instrumentalness',
                'liveness',
                'valence',
                'tempo',
                'time_signature'}}}

    return audio_features

# %%
content = {
    "audio_features": {
        "acousticness": 0.934,
        "danceability": 0.186,
        "energy": 0.107,
        "instrumentalness": 0,
        "key": 5,
        "liveness": 0.297,
        "loudness": -14.802,
        "mode": 1,
        "speechiness": 0.0347,
        "tempo": 107.095,
        "time_signature": 4,
        "valence": 0.149
    }
}

# %% [markdown]
# # Time Test Func

# %%
def get_runtime(function):
    runtime = timeit.timeit(function,globals=globals(),number=1)
    return runtime

# %% [markdown]
# # Un-edited with (Lst)

# %%
def predictfunc(content):
    similar_songs = []
    print('Loading dataframe...')
    dataframe = pd.DataFrame.from_dict(
        json_normalize(content['audio_features']),
        orient='columns')
    print('Dataframe Object Created')
    print('Loading pickled scaler...')
    scaler = load('./val_data/scalar2.joblib')
    print('Pickled scaler loaded')
    print('Scaling dataframe object...')
    dataframe_scaled = scaler.transform(dataframe)
    print('Dataframe scaled')
    print('Loading pickled model...')
    model = load('./val_data/model2.joblib')
    print('Model loaded')
    results = model.kneighbors([dataframe_scaled][0])[1]
    print('Prediction executed')
    print('song_id_list loading...')
    #song_id_list = load('./data/song_id_list2.joblib')
    # (added 3.4 sec to run time)
    song_id_list = pickle.load(open('./val_data/song_id_list2.pkl', 'rb'))
    print('song_id_list loaded')
    print('beginning for loop...')
    for song_row in results[0][1:]:
        song_id = song_id_list[song_row]
        similar_songs.append({'similarity': [.99], 'values': song_id})
    json_dict = {"songs": similar_songs}
    return json_dict

# %%
get_runtime('predictfunc(content)')
# Out:
# Loading dataframe...
# Dataframe Object Created
# Loading pickled scaler...
# Pickled scaler loaded
# Scaling dataframe object...
# Dataframe scaled
# Loading pickled model...
# Model loaded
# Prediction executed
# song_id_list loading...
# song_id_list loaded
# beginning for loop...
# 0.9916594000001169

# %% [markdown]
# # Edited with (Array)

# %%
def predictfuncA(content):
    similar_songs = []
    print('Loading dataframe...')
    dataframe = pd.DataFrame.from_dict(
        json_normalize(content['audio_features']),
        orient='columns')
    print('Dataframe Object Created')
    print('Loading pickled scaler...')
    scaler = load('./val_data/scalar2.joblib')
    print('Pickled scaler loaded')
    print('Scaling dataframe object...')
    dataframe_scaled = scaler.transform(dataframe)
    print('Dataframe scaled')
    print('Loading pickled model...')
    model = load('./val_data/model2.joblib')
    print('Model loaded')
    results = model.kneighbors([dataframe_scaled][0])[1]
    print('Prediction executed')
    print('song_id_list loading...')
    #song_id_list = load('./data/song_id_list2.joblib')
    # (added 3.4 sec to run time)
    song_id_list = pickle.load(open('./val_data/song_id_array.pkl', 'rb'))
    print('song_id_list loaded')
    print('beginning for loop...')
    for song_row in results[0][1:]:
        song_id = song_id_list[song_row]
        similar_songs.append({'similarity': [.99], 'values': song_id})
    json_dict = {"songs": similar_songs}
    return json_dict

# %%
get_runtime('predictfuncA(content)')
# Out:
# Loading dataframe...
# Dataframe Object Created
# Loading pickled scaler...
# Pickled scaler loaded
# Scaling dataframe object...
# Dataframe scaled
# Loading pickled model...
# Model loaded
# Prediction executed
# song_id_list loading...
# song_id_list loaded
# beginning for loop...
# 0.9032399999996414

# %% [markdown]
# # Val LIST & ARRAY

# %%
song_id_list = pickle.load(open('./val_data/song_id_list2.pkl', 'rb'))
song_id_list
# Out:
# ['5PS5dpaLogPzYU9hWiWyZb',
#  '41RpZW2lxAdnqDd2nMBzLQ',
#  '2poHURuOfVNbzZdivAwtOH',
#  '1jg9hZnReygpBvV2axGuPy',
#  '3GsS8jzoixpCnp4jDWCEvb',
#  '0kq75szR7uDEYrZkT2c4Ry',
#  '2HyFpkX9J7vv3OZNDaraHZ',
#  '7DHl34zUQues23s4iHo2bc',
#  '2djsaJG387f1ahzqWOiRbD',
#  '5SM86TB7dU5n9Y23wLgcBY',
#  '0ghgsfOnoXJT7jsS63U8et',
#  '094NMQnbuU7HsB39TK9r0h',
#  '5cK8MqaWsMNUd1zdvWCDGX',
#  '0lV6jCaX2eMYlca5KoGvSA',
#  '7M3syWZOykl4i8kt0RvNfK',
#  '1K7larQ7ral1uihIYzGQHq',
#  '4SwVzxCwgjLHlUn6Yxowbt',
#  '5IDGLcaHOS4OiLVLdzK0k0',
#  '0KvaBQ35eOY7qcRxGZ5nnM',
#  '7csOklK0Aou2Lf0kML3ofh',
#  '5tgZrxLnJxDVfDRaWV88ab',
#  '05xctkVGqBTDwdAU4ZXiBs',
#  '4BwRAYuzdrdgWVM7jtmqX9',
#  '0q64dnzWQCpIJpts67vRbg',
#  '7C1dy234jk0AiaKJs07Cze',
#  '1g5JkZfil7rXaN0dHbJTX9',
#  '0c8IWIbB6RoNDal4vNgbp7',
#  '1gZ7O4cSXJJRsXZtMP497x',
#  '76y5dEgiGDfs2pbi4qR9lT',
#  '1hVwAWqaIUMMzobJXB5b4P',
#  '6StJFYvHV4s5D4OMZ7TfMn',
#  '63IBFUhrX8Sf1iMzewyKKm',
#  '4F0ib6E9Gv4FB9zIqwOOfp',
#  '4JR2t58ZYhtVEAw2ZqWalR',
#  '4ooqEBmfxvXoyExzj4RfJa',
#  '7rdxXGFRW2gyfbZL9qmpTs',
#  '4ZEBxkZk9DYDhxtlmSRXnL',
#  '1RuycKhSbGlN5N2cArXCna',
#  '0wBw3pHkg67S7u3t7A1R7M',
#  '7tFb8FaTPNvK5mwrxB0l5B',
#  '2YHQHdIQ20zlB1huPyhtHQ',
#  '4nnWW43CBTRTSDhxGsGf60',
#  '4grKkorXXwb4r9ReHDUqCp',
#  '3Wq1uyqPJ2sYeOtA3MLeKQ',
#  '42vXO6JbfVag0VkE4XKRek',
#  '0gIW0Edu0SVRNUJXgZ8v1c',
#  '5S63rSc8GSeXPEZecYvowQ',
#  '0rX1eAEg4RROzzMb83NRNW',
#  '3IURLTlxIaPvo1dBkS5ddl',
#  '3hqHyfnrfY9krEHVjjRQjv',
#  '2ZuxdOMH3uyJEbYrLpODsY',
#  '7GDO9OTV43JA4uHlgc4rFz',
#  '2Qw7xsexa8pJCtUiPuovVD',
#  '60jn0yIRinsRcYpTd0tyLZ',
#  '5U91LK8UOUyTkpFFcoUVTT',
#  '72mnbEbPWUyzi8nJzzaM9K',
#  '2a71xpbaFMuUxWzwbKDLRo',
#  '5p1ltu0lOVnp4EeODqOGU9',
#  '68d6gCvA68WvcIYGsQknVv',
#  '5CqL0PxTR6jsVe5KDFhtFS',
#  '2GKYEk8NQkafOqSw4uWZXl',
#  '3nIKXtY5e9PNeTRu7TotRI',
#  '08CzvTYVuNkbBPsGjy5pqV',
#  '7ISBCJjKts7TRtEhdKaYM8',
#  '46eMttDKEXEiCvncgQm64A',
#  '5udMby0ZOIAASL5qwFnUuM',
#  '0Sv9D9aeQAHo4Wn8nShfAm',
#  '7M5CbehJR5Hbf57wJykoVi',
#  '5MvnIsx06dW3RV38kGR9H3',
#  '4KMRfG94YXm0wBsxTuqMeT',
#  '6yCLzkjB5TGDi9SvckGPJM',
#  '0IydOQHFq83WBUcaVwgFIz',
#  '3qvVal54ezR5FqctiIHPAU',
#  '5BKPh2HkbeUv8qwWCWhHBR',
#  '0DYyZC9ss5msA2qOWFxW65',
#  '3aomy4NLiy0ObQZJQWm6Wi',
#  '4gX3ltP4hdH47OKCvaogGh',
#  '5lRXtvWPHLzkVknTH1ci20',
#  '4OStqxvu2MBQq4n0YWo7uq',
#  '50ssljlD9IYwEBPSMrzCNi',
#  '4tAwP9QKeLEQJ2fgd1RWcY',
#  '3j2AifnHgbDoImllIvsNJp',
#  '2wkQbS5e6ShhMVW8sbrBZN',
#  '16Hr1REzaG3wQ9ZxwqFY6j',
#  '7jW99uQlNY8bnkUBT0ilIu',
#  '2W3m5KZlBs9htZ9ShWZJHR',
#  '1e6JDjO5ZuZrCFeZbVaN05',
#  '6GELJYrNmDEExuO5135JMy',
#  '5q7Drt8AVfVJsJf6kriFc8',
#  '73J3BbMMEpYeU0I8yni551',
#  '0Mw4q6FtfAmATV2rj02r04',
#  '0tjXELjWB3Aglje1zWPbLv',
#  '3itgHyopxa1Z6afgQ7bph2',
#  '4TTgtzOnj0QmXUz9ZXgxV2',
#  '0KdycSvLYjCbge9EilgUEu',
#  '0vhrzwpl6tDEhPTuhCQTC3',
#  '0HHDNCu13KNe7oYRn3BYod',
#  '3qy1R4MC2pQSRcpbz0hCHr',
#  '3lSwltdBUEZIgwsX059dLC',
#  '1gOrf4EwugWtKcanwuyByp',
#  '1FoDSJ9tsNyyn9pEjvpcHX',
#  '0YxgETKHayjfYMws5jZ9dw',
#  '1DlbcfoBS0zdXtUVPGbQuB',
#  '2BaxmZ89s5d0Yblzkj5DLc',
#  '63ptUYad90SWUQz8eukxUo',
#  '4IQnn2fg0KbMVQjtMA2ngF',
#  '1VClRsKcM73swoum8Fz1Ln',
#  '5wn9aIUY82QXz5f1gOvJkf',
#  '2YP79XB4tfeGBYDnj7gKZK',
#  '7sHKbVbxk1h67kDwxBYD1E',
#  '0DAUpAMxZduImdwDzntISu',
#  '7IrmgUGkxCnFThgDuiybcE',
#  '3kdoTahAD1F6Rkf0mvFHzC',
#  '2DJ44wRoNceBbEA2Kpq1r1',
#  '19OpNwxMRIQMhoRNU0yAef',
#  '03B0yrE4zrioHjmY05l9xz',
#  '0JSnkFac4oc35Ijj1qR9j1',
#  '66D4x4w1IY2naJ4RKDc0e2',
#  '0oqGE033PCKSxXd77bAZtm',
#  '1YxSi9FyddtJbtRgDvNQL8',
#  '2snlUv76C6gEJ4jYvi9F0S',
#  '5b6Y3yTLSgfXaxMIS4Eyo1',
#  '3PH1HNJg6hwC8cuOYx5ehn',
#  '3g1PW1ovER6W9FCpN1Ka7N',
#  '4vP7b64xYV4l2IEYcQcfn1',
#  '4LisLrspORq8IagdLHWkf7',
#  '5w8WwjCWfuHWl2x4zLV3LR',
#  '6yACAHQnGHIXxCujJ9CQRr',
#  '39bfWq5M6SqW7trByFkaTV',
#  '4UhIZNwO5ELuQdvXj3UT8V',
#  '7EmDSCf3gRMuR8YOo2GBqU',
#  '0csrO37WfsnIghedWjCSRt',
#  '3ZSSnq35gKal09waWnHLSm',
#  '26YZGPrJLhT2Y4vuW3qW9k',
#  '5i9ejFPQsiX0A6DTvhq7ZZ',
#  '7DDJRjcrWZao1sJ97xj7pG',
#  '1zrnXFkQ5AD0WvdemTWmV7',
#  '4aviAvUyCrSKABu5zzzayO',
#  '7ArU2I2gqLVNiXNF3OUpNg',
#  '6wpAhuSTrYf7FfAbgOwBXY',
#  '0MqSnVPC1nVt3KMWO3kqmJ',
#  '09CaaBe2kxE6a0gH72kRcE',
#  '15eLMiFCUePQHC5o43rZ5h',
#  '75be0CAxcBPsyccCK3D8Zz',
#  '1oMVIfiOUXNwcJfvBLgGL4',
#  '2EqYU10cEbr5OUrSuD22OI',
#  '635Ujx3WdgItUKmdhEED9S',
#  '3JRPxAfuVximgKti0dTVV3',
#  '061naC7zGLRMkF3VYlV7T2',
#  '2UTJaJOIqMBXkUKaQPGxgA',
#  '3EgkF1mUzKXiyjzxtuTjp9',
#  '4hDktSn074uXME67LhBRlW',
#  '3kh2OgUmoXvxET8Ocd1Ezr',
#  '00XerKFxBD3v7MHbnksyQ5',
#  '4KyqiDc88U6JuUi4UjrKju',
#  '6boTsLDa5aOoY1WbjJWmEX',
#  '5emxS2ghZWuPnRFOe10vdq',
#  '19MQNDiGQzd4AIJoZ2tihJ',
#  '7xZyoel8PsRvswzqPmLM86',
#  '2Fh4hZYxyI4MY6g2hFru1b',
#  '470UOQDSTMTBEgkBaeqVN6',
#  '2FCOjJJvP4uvoPB3GgHyF3',
#  '3vKcsH3xC12I4nyjpIw4GF',
#  '6OAy4IjKk8OiKDNNreShQz',
#  '6SPM9zeoluUKRe69dcHstP',
#  '3Ojvs6YPLZ4BImL0uJUH9g',
#  '0iiboSu8tNPeVt1x2Xgidi',
#  '4Q3qMPIQJviVMFZZkwLpFJ',
#  '6zSsNN5vXT36NvpoAmx9Fh',
#  '25IjIhL36Bh8zMKl2Dmvzt',
#  '0SanLvXc3eSY7XqfeMlDOS',
#  '6vnHHqwogh9t48kzGpk7j6',
#  '34FuvzrP8PUJdfTviXHm4C',
#  '52LVOolmOdXFYVvJMblay1',
#  '4VCnqrxrltwPWCtePMW2tr',
#  '0bMUl9WcFOsXgTVfgqMLCu',
#  '5D0RA0myEqWngylNJq3FRU',
#  '10bNHQk8gtNxpY0SBJeD8G',
#  '60sBwoavEvAbnIe4Q1mRbe',
#  '2JBW7GNdsOBZent3mtmZt3',
#  '2L93TdW2GMue1H2zlkt30F',
#  '0O1gRqbxTvy9hKMMMeKW00',
#  '0LtMz3DJdsDlH10rVM7Xyn',
#  '7xCWlfMs28eIOkORYqbhCA',
#  '1eJGGhjDaM3macBOknCHNd',
#  '3TcIDcSU4ygjs3b2t0dYnf',
#  '2YnFjnqWdDvrc5L5UWIF70',
#  '2YwQ5SGIBd1v5uQ9pspkNB',
#  '3kMH1xJWLKylvvJ1q75JiG',
#  '0q5bUMYuqtBwCpfFb7Lu8E',
#  '7a4KwkECcUmOufts3IEGxl',
#  '73IMsRgoRnazb8Qpw9bhbi',
#  '0BZID4PDwC66nM454POSMR',
#  '4I52I0c9wuBUWfieDWCf7v',
#  '6ag93gpmAvbo2RxDjjTovv',
#  '3lQ8iibLdKMm3AU5o2rw1t',
#  '01Kj90bLob4cpm8S04Vv6K',
#  '79JPjsLbTA3mJfKv4q9v11',
#  '2RCQ3n2nwfvWpf7sLIUZmQ',
#  '2SQUv0aL1MTAaQ79g3o307',
#  '1rkqeRq7jLoWMey6z4mf8f',
#  '2nYVA2MHdmpcLP3h1XHTd3',
#  '1b4TfJ3uMRUcGxUSRAgADA',
#  '23hWrtyLFw2KlwAhmMFjoT',
#  '3kVCz4WbYhcddxDrHenI4g',
#  '1xZ6XBwdlBvWUU8nSpHBNt',
#  '3e1VHXDBVwzKyFjrofub8T',
#  '2Z2NvnB2wCXcwEb32QpZ6J',
#  '7H5a08h8VF3YYNvjj9Iqiy',
#  '29DV64rUiY1fWGWmuMvDrX',
#  '1t9bX8zzjrkyvwwjlSzquB',
#  '1SpFB17XeWAgHWgWno8YTb',
#  '6py3nM4CTL0GlCkcFzoFYa',
#  '3EbMhhC2rjKqfn3kuv8wIR',
#  '3jF8SkwgZglAoToddtM0GK',
#  '2yTdLp1zZ64lx60EyxFlBE',
#  '3s1cJ9GXSskfXNaUYk9Zyr',
#  '23Hw5riR8D4aFIjb8zhBSa',
#  '0q8HokFvyN4SyrvLvGLilD',
#  '3rr9wotLGv4zDQqOAaQ2ee',
#  '1Ka2p6syWPf6knte35uIM6',
#  '6ePKDumpzn2MHhqBbsueRD',
#  '7yQK7wxv9a2AeTu20rKob9',
#  '6V7xqNPNhipyjUKvXfFHCD',
#  '4LIC6vCYj68XxCTx0xI5pw',
#  '2dZU4fuWzRIrmDz7V7y35o',
#  '6gTynV4nOsbPyvqKn882z1',
#  '4TVqp0fRNz5wgRiOrzZu5p',
#  '5PXh3ByMYeMxXu0kTguS0P',
#  '7ndmpnxWYetFrQwMwsirWl',
#  '5XbT2KVZn5tP07r1YljZCP',
#  '4r16M8BzgI45VgpePvXYbV',
#  '7xQUAhFCvIPGFYGf9rrbcl',
#  '4dOCCgK1Lyq0xlnWxXpxC4',
#  '3Vvl4IhROMjYoEQpz1IiN6',
#  '6v0NeuCZgxQFKDvw5nztvk',
#  '2DOodez0oeyrSWMe9OveKM',
#  '43bseOXJ6xPaNnmIKaLixm',
#  '5yK0ABEu7xRUXdPNDQnZ00',
#  '4cwuNVB4rrBBh3d2vKKaL4',
#  '2qpgSOhv03uuf2nutA8rSg',
#  '3DQv9dTzVU9C9tmBq9buID',
#  '6N5L6yJ9Fwl9zlxRWYip1e',
#  '6JfqklQTnnWbVEurZqMFSZ',
#  '60UmAL6utKvTwAXOtqvkjX',
#  '4ELSyxd6DQ53eRxYLh1FPq',
#  '3RZS443azLTWIiblAg1EiS',
#  '598vKsOHU1PTVfaaW2C8nx',
#  '4SI5TeDJJJktaGqzz3FMl0',
#  '3abiAJkcPsTv9wo7im5CxJ',
#  '5TmPKtsiWe7sggWulu8HtH',
#  '0SxnU4dO61cWyTbCVqD5sY',
#  '16ed2HdbWcVtIo9Kif2EHJ',
#  '5VkOkl4Gu6YOLFX0HTJjsx',
#  '5xTwyGpQzCsuI2JNMai4cE',
#  '4f4R0p3LwfWVDJye9B0odf',
#  '70IZFXkUM8EfRhlc9DsvRm',
#  '5gxEaxmIQ9QLvoxoueKa4y',
#  '5MuclW1eVqhNKmgnVEHjcw',
#  '5KMsRKrzfL8gfs7vhLDEOq',
#  '6CtaPSyIEzRXjvwbPm6FDG',
#  '70J3ZOS7Y2X4YrnVIwuueK',
#  '4JBaqgG7Ou6nIfD3gkK5qD',
#  '7n4iVcgzS3iUedqk6u2HxV',
#  '77Z5By8tADuKveIFnDgwO6',
#  '51XPOm6ky17APycNWGrewJ',
#  '4brxErgyyAdhyNyDyG3V89',
#  '24Lh76nEtgsR5vkra1xqtK',
#  '74LtuhbT8EB2HHkw8hNfO1',
#  '2OPLkn8zc1TSCvEm7Xla94',
#  '1r3evXQEmFViUoTwjOeNMS',
#  '0XDFNopNXhs3ifMDvtU21x',
#  '1IAFNygm97YjI991ilZDVL',
#  '6W9GnyJDBigvaKgtXz4muU',
#  '7sPEJjKaKCht2gfDWYnXbr',
#  '1n5DgEYw4WPT5BSFKftbW4',
#  '3SwsGGZn5E6pxdJgSZh5ml',
#  '67TFfIgMiUysC4eK7Jn6u5',
#  '5XZZcj27NQbJq0xtHvh3X6',
#  '1GKEriDs1OVIbao0dGb0LH',
#  '0HifbiX75Hi53Bg16EMTLG',
#  '0GBCthmzUOiuh0vJlKbBnH',
#  '4Sw4lblE6aXpoOJma6Mlx5',
#  '24v5x3j1Ki1RTK7UtlVbvd',
#  '6WplRyO2QetlmfCbfEpAfn',
#  '6Jpx7I6v9nHUgeEDtX1dr9',
#  '3DUCl9enAa3w67wC6Hf128',
#  '5bHDBC1SQBsf9SJNk9IENv',
#  '3iEIUK2mjiGzhtY5n2ZkIg',
#  '4rpfA2rFOC7FMGxFNktB0i',
#  '7r2ssl5ciiXfJ57gpOEiZK',
#  '7yO4Pw6z29mkCtkUubBSiN',
#  '2ONNkvGUTNhobillkJGu6h',
#  '2ccfBDNTAZdQblDowhiLvR',
#  '0NJC0FDCODpPUntRTTQq97',
#  '5rcW7dMbROenEXwndMRvzN',
#  '799jzpGalvwbHivIysNpqU',
#  '19KhnaNy1GS6jlxc9eINeg',
#  '7GkPkRgbprAK2HAbSSawBE',
#  '61T9Rg2z6LGdpDeQqDzgFj',
#  '1ws4pZoQoMAw04wn2zRCgH',
#  '3uGM65zpkqsOXsxFwUv1ls',
#  '18HQrtNFcVpcYtuqKdLgeQ',
#  '5VOqIZZEmesLZvP0Vzc4xq',
#  '23UGJYEdGJnQ1zxjhXZjg6',
#  '4G1YF8vjw6LpI4PlJwfY9j',
#  '3RcA2ljJutwBombTcw412S',
#  '4O8ovHm32aGpNC24pBv7kO',
#  '5X2N88a9W6UCIaOVZLUlvm',
#  '5OJIo0ozkozVevY3wOYt5x',
#  '4NHywppSq0JNtm7iDpTjs0',
#  '1XbRHOvUHuwsGE2YFQrzwf',
#  '6MhzEgKtdj1jDaeophCJtD',
#  '2TuyY7LQRnvUGMw8vHsVzD',
#  '5yjOnfWqQrRQrhWeISxVbS',
#  '5LfiWk07QXnJMEfVLvE5Gz',
#  '5B1TaAJdMzMluOCKFrorGO',
#  '2MZL6ROpQjTf1YhIUdwxDJ',
#  '1WOhW8xSfPKyQU8f05lxqp',
#  '01r2eLFAIbYlHroSjx20nI',
#  '740P5u0Jj8R45btXn6ggae',
#  '4nwShw6ab730H3CJXH8DRc',
#  '5nFpF7jUbVnnDMXIu65aoh',
#  '0UgtEERjKrR4gtDL4qJeIc',
#  '6wCipsHjrY1fQtTB2gn2s6',
#  '0sJ9wbuE6rGV4gZP5bwnuN',
#  '61re12c5kUu4DL8Z7texuf',
#  '277gh8I9r1DO0mj4zdcEGN',
#  '3SKZZRtI5j0aCyIQGXPqsI',
#  '4g0k6fC7VyqFthHI1p2lg8',
#  '3nasqRSHvRQrpRNTlgfDeL',
#  '1UiltFvkTsPNyVvk9KMtWi',
#  '1bTokNLxB85koQa15QUdGW',
#  '0DVHR5FQ0Gp2dsZJz7hfdy',
#  '3jjYX9Vk0tis2jUyDb88p1',
#  '5CD6vGvX0RA6yxYGpCrSo7',
#  '6g162raOXKthuGhq4DiK8d',
#  '0DbEVjGwUxAdZJIL3cIxJR',
#  '3crVFTkZFrZs7NNrxRv65u',
#  '4sKfnz409L1n1o18E4jPHC',
#  '1O6BWU3EA0YIOVJKlHOhy8',
#  '0wJ4V8cfzsNqXBZBPuOkKJ',
#  '3pDbQ5koZEgI8418ckIdIL',
#  '4rrdnPQTy48CWIj8RZOUkl',
#  '0gtshcaFPK8Ze0P3RcWsCK',
#  '7kGz0BrIvtN9beJPZihX1j',
#  '59TDQxuS353LeL8pXTKQwv',
#  '1ch9iGt6dXIMRANoZGKLoF',
#  '1hwXL5Nk3hxp4a26Ii4UpZ',
#  '0RS77knhxuGpEZxdmxy6vc',
#  '5yUX34IdTnbGa38yDWPZgJ',
#  '1rILVXDGk23m2oopCdRVHe',
#  '1zcI10Y8WIV6SfdxTNuQB7',
#  '0fMikwtA0L7QIT2qNDR52h',
#  '31nyALkcNmZYWehnhI4CMa',
#  '5665vLd2ta7xhPI5QfTJ48',
#  '4CgW0OIhoLIalJCYocld0u',
#  '4ybdHw0lFe9KLdVxl9XdQn',
#  '5L9YIhlRU6wCRa65j7TymK',
#  '3kyXxxkV6PBYXmOSVREqck',
#  '2vSfAxEo8x5gLXJJoqiNv2',
#  '1q7Gf4YyAk5GynatUD4toG',
#  '0h4PgGPGCAoBqe4cBUAeSx',
#  '1f3ikBxvuLPvP2Qo2FPJRZ',
#  '6KWDWLmHsK4uplsechmdsE',
#  '5wZKxwkJyOvmDs3jfgAw8W',
#  '1eE8WwUo81sJEgDzrTAozo',
#  '6kAIOOVeF9nYbA684JAmD2',
#  '37fRoLTkPxZnvT2fT5opHD',
#  '4gtNmRW2N0dX71Et25HhRQ',
#  '3DnrapTfrOCdg0yOsF3Aoh',
#  '4a3qlzZh1ymQKgMSbqVvDE',
#  '7MwmdEu4hpIkJZNQNtgVCi',
#  '4BBRWbh6HrU6w5jIKZx2b0',
#  '3CzsIcex0J3IMSLL4c4noX',
#  '5OJY5xfO3i7QFgVgHh41pB',
#  '11JqsjAca20DpTsLTzD8HQ',
#  '42KmF0AdmLGpOsom9TGUVk',
#  '57I5xU5EpKNDQFebc2aYjs',
#  '0DMzmgs9H0kN6Qa6N1srZ6',
#  '78UI8QnQRSDhs2FmGQGFdf',
#  '1ljvo1b964O9EK03ABmlYc',
#  '5Bahk0cg3YRyVwssFHpN6L',
#  '2ZH6fqwpQWxX3Ha9gz6Lep',
#  '6ClI69QDQTF2XGQ0US7j4t',
#  '2xn5rn7mQK5HYPNfoqOoIf',
#  '5auAkX7cCobIJ2leh6rI6y',
#  '0CGaC0J1HHX4o7DeY8bHss',
#  '1roqUL7dnkn9hrmD5yPSMo',
#  '28y9CI3FlWrLvFDQCdCeC6',
#  '4bn80C1HckmEX95K18xsV3',
#  '7ft3aBC4wjJ6Uh2bhBiIwf',
#  '0Ubg4GIQeo9BTutFFcmZdd',
#  '5EeQorSRX9mqpunoCFewDE',
#  '2za6Ppl8vsVpBNUROXtDLD',
#  '4uAfok8vTUGnKCxYdvzRYX',
#  '28ue66GWse7OSSNo4XwBHH',
#  '24SkMaHSHyfiNFz3e8BtEm',
#  '5U20ZuHl6ccPtD0nsypyUY',
#  '6NFy1XosWVCBXwQhQ1hMBi',
#  '3LQwdzBBBmLQlTZ2ucApl1',
#  '5vGZV7I0HgxgJE62DP9gG5',
#  '7e7C6ZJ9AZ5UkUYRXBCYtB',
#  '6yrl9p4rgLcX5fEsG6N5E4',
#  '5L8tJvOss9v3zCITgvsI8t',
#  '1mHsRf6bVEv7O1jwwjNaIK',
#  '2e0lS5SFQQwZA0pICuwdFx',
#  '2cGrUn1RXvOSO6ltEOFXEK',
#  '2LA7JVrjWM1zfb9GnqJAda',
#  '1CNorgh12aCFcen8oYlvhG',
#  '2WuSpzSBRO7MeVQDp2e3WL',
#  '6ALaxbuQ8no0fAqjaICxCL',
#  '5HcewUacTyly9Ob1SPbinP',
#  '2a3SEOdx52ZDMqpKcs3xVp',
#  '6wRGwdX7IoddmLrW2o8nod',
#  '23z52XOA8sCAMC41T2h6QY',
#  '7qwWx50arhKhJ14LPke4Bg',
#  '1J1TpXABHsvNYqeLXqh7Yv',
#  '4vIn9ecAvhj5OLzkBD9Ius',
#  '7DBAqu8qewtTfAARdvmxwe',
#  '0NNTc1hX38zCGS1sS2dfBh',
#  '6FJtGQqskDAdu6LTD9JFT1',
#  '065tQiNTLxTtOA1UBeJym5',
#  '0E6GomNmdQjgcUuRaJrVQl',
#  '6lIDfZH7tMPlkaRwjCoNZf',
#  '1JlJpjMj1gMJKE61Q9cUoa',
#  '1Wh4SWfuuUN5jatR9N6xqn',
#  '7GHHZJ0tQu4SVSzvAKus6R',
#  '0vYTDbBSKnc0AhJwb6Hnjp',
#  '7GvbMffKtC2RLLayQwmE1B',
#  '62jQ91SnJT45UPRsptU52b',
#  '736RJotUAI9dSfNvwGqMkI',
#  '6MXiTkeK2SP20l6Upf3Jo0',
#  '6nud56OI3XQrWmgwGP26S3',
#  '3IluqmASTobebWmN2Lsyxv',
#  '0PFJrTRgECeB0utx8Wh2Q9',
#  '7Kt1cz9dEQC9IAhUkeyEoJ',
#  '1wKTdEniZT2LXGxi6kgEw2',
#  '5Oka0viqa2oWt6KyFLbeng',
#  '0qTuZnzVesn5mk1DZq1pQt',
#  '0n4S0eI4wU7t5ez8zcdUW8',
#  '3yePS2zdDDdMjqupeCL03L',
#  '14BeDHqf4FWhhTPH3787S4',
#  '31hfI0AQXqPNN2P2S9aIHs',
#  '5CJXhZ0JixmeK10rYBXCqh',
#  '4vZqvpR5p3wG7g6DgPcFnA',
#  '5fjqJK4w2PDIIlRNaXoVan',
#  '5WMKS1iDfugyLhfibIlR51',
#  '3ghhd7sdIcWrWL4yeYc81Q',
#  '0Vt0vGH1yP1DZaK9Vd1D6f',
#  '1B7kYJ6D5e3kknm93pmC7r',
#  '0mhoL2RbLuGAKeAfr171IH',
#  '0mudCtyjIJvxk0MDR6LAPC',
#  '1JKZVW9JmVSsYD9P0GsqMu',
#  '6Y8KQjq45rPT4LlSQecgpJ',
#  '1kmSeywVbnlXWMO2c8wa20',
#  '73zQtDnr1FTTL8YEx7Zczw',
#  '5dOWqSrkyGssKuf4vD311r',
#  '1Fi6FUSEFvfge9x6BjMFys',
#  '02m8MehnvNJBxJJhrqWSMh',
#  '2AWPcv9rXHO2vcAixbAupO',
#  '5zg7ALnOpsBwXYVzCOuWhc',
#  '3YR4Pw6Q9hfFhi225LbQUI',
#  '0GVN0dKV9Xi6HfaMIuCmmn',
#  '17ifyi57ZbOEX64AMxlAnj',
#  '1jCFnbL30NwORyVsiHX6mH',
#  '6J8OKCJz5qyrivr6JnZcP7',
#  '63ZRhiWAKi2BrmrvFROCgf',
#  '1T94I4WB4qN3KisLZeWDB9',
#  '175QcGv2tkFim3Ak26HXl9',
#  '7lwtDjS9XQhFRstEzc4baV',
#  '0CxxMem0uiXN8iaufqHc0a',
#  '2iAXCbsQmJqhpGItN8cRU5',
#  '2ewbtB0DZhtkoFALbJhxxV',
#  '2FrlDYUqESlAHA7Okzmfl8',
#  '0i2iamrP3MVHpGh38XxZkz',
#  '02POUd1I21bqP9T3xSjo1U',
#  '1zjjycn93jLHoPkuWk4TEL',
#  '2DkVPuWe9P5qPOjTzShfYN',
#  '3a1BBiU9CXx8GDADs15Og4',
#  '7I3xVAwXJQXsLXAaVXz3qo',
#  '3MHGGmWZrCMgRG1BZBgmUL',
#  '2ezhi6YD6mGm3WWpEN67Di',
#  '1xSampk5mCARHPM7Rm8F0A',
#  '6USRodkfFNJo1E6S0rhVPt',
#  '5kFXssQcDX2MhAlOcAsubz',
#  '0oyTrpxh7WiBtYB6sdocXB',
#  '6TTfmNTYWnpkeSNkmpQ7kl',
#  '7cDQqJudHV841u8ibcSBTA',
#  '4zJ2eJ7jqDBKC6iSA5FPrD',
#  '1CGgKDZpKWiVEWMzCh8Ddu',
#  '3OS3C5NrmRuZ1VzPJxnbF7',
#  '17ABKHcXMB3xzfB7heOeUH',
#  '2BTt7BEN2CNAINGuth2nsV',
#  '5ZvKMLcT8q4hhYikojY4wy',
#  '6U5Pc5kudpausQldRKYqEj',
#  '3pCi5Tc2OQ69FesdZ6hAjv',
#  '5DN5ozXDMbv9h1hiaGcZHj',
#  '6B5inOZyQG1Qjjc6EySIVe',
#  '48pbE0YIdWA6LbcXGM20Ko',
#  '67pfiFoxUCSEJlh6uAdWPB',
#  '1Tb02zBwAS9hXDhk6Dzpkj',
#  '0usc4WWWWeBuqj1uGVHV4k',
#  '2nSny8WsM4ZysM5ZLcUhEh',
#  '2S5gsPqtcWQfMgXIxXjgav',
#  '6rI7zbL3O6xNDj2bQKM0b3',
#  '08GIu4b4J83Ll1lvSBUPjn',
#  '6VHSNwXWtFTPpr8mQ6DOV2',
#  '6sF7vg3WT8hLOc1GCfgw6O',
#  '3EFHJGVN8JnehKnMU3vFCt',
#  '6xInwDFlB1Kk0UlUwpnFoo',
#  '2DUn3XNY0rba9VXIRXsmAw',
#  '0NvyoxhUeVTE6VH7DxYOon',
#  '5lZCJjOUpBUYQRhPXsTS3f',
#  '4DKMQUBvQlh0BYtjLtyKHP',
#  '5GwlaZYksclv2EMmRzSXof',
#  '4FMwiSRWoeYjtbKb1wvscf',
#  '6kj4vNtxFCgPDaDB5efjDY',
#  '3yzDdKgcD6kWu78nhfekYl',
#  '46AkJ0uj1nEfmG66oW6eTn',
#  '64RnIqEMPUPx3MTzPwcfKO',
#  '0clYDaNptY0GJ7aXsIt6w9',
#  '23Zu5mOExqPnjjTDa2hERT',
#  '6264606clUKLnJ6TsLdGwM',
#  '64OCsrNxsPH7ajs7M3ZWo7',
#  '2wIst1Uxd2m9nIoJ0VJN1F',
#  '1YDRKMdrrC9xsagyg2Fbbc',
#  '2c1j6CEBnao9e4dhlYYXvR',
#  '77srX1sORCC3gNx3eDwbKw',
#  '1U1jzVBNrWejWUvNpEAk40',
#  '4dvIpm8IjuQjVbt6zmoKFS',
#  '4SrreGX8YAozchLHX8ZttS',
#  '4W2SEXGeAYtmZFKiUXM8Qh',
#  '2BNKs2TITkmR4cnZdBIPY5',
#  '4pFdkYXQQI5laA1Ojr4Zok',
#  '7siimgl9ggyJAKRgJ8sqm6',
#  '5dfamFezTib9fwWIW022HG',
#  '4KPZRbaKFKXx8EMwepncxN',
#  '5xmJqauthqiWddm34QDY47',
#  '1BQfh47ctcxrbkpPCpKQAj',
#  '2SaeknEKO42LfEWG2IVV8Q',
#  '4NHySrRExaC4eEIBWPp2Th',
#  '7FtNWyB4BbsLQ5geTLMiVj',
#  '7uaB3KdPCF4AbRTYhvjoQ8',
#  '7oGiiIZGGXR4LNbeaKeCLL',
#  '6t5TFMtERCQ1PpzXpeJpF8',
#  '1zzVMuxb1yxHS2GvtgiY7m',
#  '70RJdzLuZdmNHjku37QSWO',
#  '1sjP3Qp9WQKugirymBwCFI',
#  '5vgkkKDPL5q8d5oA7JGJqV',
#  '5YyPNJp2AshuHzjaViQk8z',
#  '1RuksL5A0flGTgSe0Aej3b',
#  '4RjpRcoxpzjxh2I6niRUz8',
#  '25NahypC77gdxhSzrTNQSA',
#  '5HKjmf29Oym6yAUASbKtOs',
#  '5cvFXdgRvj4LantHdm12cp',
#  '6voHpkaPI5oeGCkDHBtXAy',
#  '3hJAPExTzoNPqEM5k0KxN1',
#  '0W71Ai0kxmcSvC1baXwftY',
#  '6PM6QvJEHSz2AStLNdGPrb',
#  '6KR0jxaH5fEpyysELQc3P4',
#  '2wvfMTbZDPzpZhOt7z6tVo',
#  '4O0Qii0PUwcdJkyyimguAp',
#  '4jl7EVuYjKpWyjUyVoVu5n',
#  '21DIH9uJHoxWL5ztbA87HS',
#  '26BQpH0LF7Yw74EfePlLyx',
#  '6YdpcgFOripla3UpyMUbK0',
#  '4ZSHUnCh9zpH9PMhnhaZ77',
#  '1hO37cyOJGPiANQ038TAAa',
#  '69Xr5I9q0lmmgbuXSGHeoE',
#  '1yGbkbw0nLte46M4XYAQRl',
#  '6agmhXMz9WLd7QYlv9fDbe',
#  '2hk6GaLo88w6beE2HQD2dA',
#  '3pDqUU1S1clhzlo5VfAnhX',
#  '23arAaFdR6cV2n8lqARvAg',
#  '4GH2KFMid4AiwlTsRUtkqw',
#  '0wvlASdMFTTmEn3QrxxgIX',
#  '32QelBMxy6c4RXiWeWhfXR',
#  '5ZPxYRt98eo7vcPWHFRCM7',
#  '78jD40jfgw0IFGq6jdECzi',
#  '3mOxUOn2mAFxXXIBOa2F1h',
#  '0GvH1hKlYqzLZqQMcVIxwU',
#  '4qosTSQ6vCXdBpZzoknaxe',
#  '3aWRBYgaz5g1iQubgcXpG3',
#  '1sgjFybDr06WOrWcDcoXYD',
#  '6uB1jPS6maasodaPcJbpDt',
#  '0ZQLy1ehM9CRiSmlzznTeQ',
#  '7kDsO94x3cxO132eJB072X',
#  '4VkbbHU5EvhrOnjAYYFDDT',
#  '2acviU5EIsSML8ntUIY0QU',
#  '0f1mo1HpFVPfrSjDTOoZiw',
#  '1FVxkQjj4cgJZ0YkSSTopu',
#  '3JBt8Q3CnL8lQBafNFwDeW',
#  '5egdUWBV0NKexi7XnlaAG3',
#  '7ylBzivReDbOoIXDRtsoZ3',
#  '1Qwxa9mY495iZSsUiCEP9o',
#  '5uepEHb41oR57GDirm7HfL',
#  '7c2OJjtwavhP3pYgc6K2Rx',
#  '6g4EhI5IGDna7mvvMXVlAV',
#  '3HideIC6ewPDkBzhzQuQe2',
#  '0jilNWX27RjqrPBo6iS8TW',
#  '1pGwlfkrq9ZGYKbSBjzdzA',
#  '4JgOHot4DREUhcHLNQXi4l',
#  '27mdmXNcO0gNpXlrWi9DPZ',
#  '5JXKnBBTxYDZsr6NoEDAnH',
#  '5ERVEOOSvmtRmJpbUXYhug',
#  '7h1UdWf4vB3q1lRMQFky9O',
#  '6keDSQbjh6UlDF3b3VDZCC',
#  '78RmI88ObD6lQH3JsmSUJE',
#  '1P6nwye7hubVhPC5sYGiP5',
#  '33AFMIAdDtQJ0cMIJA7ZRC',
#  '7m7rSVIXkCbzT0Ag0d9yhT',
#  '1qYVlPNXvwdj2RMEE52cG5',
#  '10p1pTs8s950op772ohDq5',
#  '5FHOK3n4qodjkEqaioxVqS',
#  '11bnKH8HnNehVlRuyMluJK',
#  '2yVhdgjCt0T2keTR1YlKEp',
#  '52d6CvA7C0NwPmMwN8fHki',
#  '2LOpiwiTotHYJFcHPSNIEB',
#  '6eAIoTePVExUTYnTgBUzfR',
#  '62t1BdFNDoItxsPdoAPvmf',
#  '632Ltwll2ps4TzyQdq3Fib',
#  '7EGRY3pA0ROzhV28FNWuk6',
#  '1sXMzayrqwoHpAmFks6lpB',
#  '3SyZwrjtLZ3wO1nQ7c6bOm',
#  '1DYqeZElTYjjntbl9DrRGb',
#  '2L9A1x2Pks64qSKCoosTOK',
#  '1bhmlojQ63mK7ikYhEDjeu',
#  '2UZvJWYp5xyM5akZ3FCIkL',
#  '571BYmfClI6ZnaAS89vs0a',
#  '4iH3TR1vB08dHAPyYj0hxo',
#  '6wwC80biLXAU9kAp4s8hw5',
#  '1e7STx9B5G5UI1U1uaX0fe',
#  '6P8gEPB10nR3RwU3bKnQNL',
#  '3APDQzVaDiUh3lQgU5Gqd1',
#  '1mePf0UXHerfyPNougfoLi',
#  '0A6ZnyHdrvSCbBbfLaB9at',
#  '0cG3IQTHk9aR4EfoKU0Gb9',
#  '4O3liHIexhPf4jy95wMsMJ',
#  '5rxHnt9NsCR7EqCb3TmGqp',
#  '47SBCrzsIxqa54IQ1t0PqK',
#  '6un0o8oAr8u78uDP8zkCSp',
#  '4cMiXxnovBiLazzI6vZIae',
#  '1Wrixw34y8suPcX69iDzgl',
#  '0trzsCYChxBQclJNU9eNkm',
#  '3OLl0nWXBRdSlT3MMCYZR2',
#  '03xNWi0ETkPO1sczIScdZ9',
#  '4NeO8adAgzkvjelL97exOa',
#  '5vziwrGUE09M6tJZgfXpng',
#  '5OQO6NEs89flntUWPtXUiG',
#  '1R0Afjc4VVVJVKjG14RDdt',
#  '23YytgUL3VsLYuGEN6vEKL',
#  '4XwjsDfzlgsTz6vQv52EdA',
#  '6fgOmWPX8eczXctCxOAJac',
#  '3YRLrpKikVQz7eAQw8KYSM',
#  '3D0q5faCEs8fWXtvE17Fg8',
#  '542vQSqmzziiCwvRLKXjLy',
#  '3Mc5wlUNZjze671miP9Mhe',
#  '6MfCcMZxXwYtwfbXhmeLvc',
#  '5AfVxs2DMN5c6Eyn27fX32',
#  '6GO6ihaad5lXa4YJzYNzit',
#  '1a078z9DPnecKFbzHaljhp',
#  '69SOQow6d1sRQMkbSJmt5x',
#  '6vv1oAUQo83qGkdLeWlXG3',
#  '14uDezpaKU3M97rxzS0xMh',
#  '6FzY4UZbp75l8hVf7gD3FE',
#  '2bGDzW4IT9xXSB6jwxcRie',
#  '5p3JunprHCxClJjOmcLV8G',
#  '3c1HTJgoJb6HU5jxxkK68y',
#  '4MY1AnHSfKzvyzAqDm5hxG',
#  '5faa9ytt15RqSUWYNzw4Qa',
#  '4aaPPNTKJdz6XBpx8kTlcI',
#  '0u0H12gK5ReJ0s43pj3llA',
#  '6e85W06g7ZNECB6uIFDb2R',
#  '3SVPy7R91VT8gZccQG0xTx',
#  '07XXH6BByArHCUym1bvALj',
#  '2t1J5JFHlvTHBpS92BzNkw',
#  '5MWhdFVjKqUranqierAYBh',
#  '29tbohwgEZO7FWqIhmTJUw',
#  '66rrPKc4cWtR52tokFEWFn',
#  '2XPluVlLgl4oe7fu4HgGmR',
#  '41E6FEuRCGQpJd7Mzdn6sf',
#  '3AX1qeld7zU9aUpfccN0Uf',
#  '5vE0u9ZKJqwAFTMFkFXP54',
#  '5rnv0goABiSXO3RcS35b16',
#  '3VcLn9YbFiciBPtu2csaMb',
#  '1j1SEf9cpBQ0azBl7qKnGm',
#  '1SUgNJtRfAiOq6CTiidFz9',
#  '3bSBFgaI9gbdfW53GwX6qH',
#  '5YyFXhDJB3gsKabjUJqLZi',
#  '6zBxLxT2ani7c62SlVGNsu',
#  '37jiHkOVx2Nawe79OEcSAA',
#  '50yzJgqyZ3U6gsMaPBeb9e',
#  '3adbe50ASMdKtZvsb00XmK',
#  '2xyQ5JTPmz3MteCTxcB7ED',
#  '0ph1gPFT9qC1CSs7i17d8K',
#  '65vfVmMkBs9z1K1sgviVOu',
#  '1tl3XDEZaJ9gPmbG6EJFFy',
#  '56SyuyBiA16nQbGo4WP1yV',
#  '7cp5cKT4Bj8bRoapSsfpbX',
#  '273TRvVUsN35o0sagShb4e',
#  '3M6HwfQdxTSUgFDZpWAGqB',
#  '1fsq27dQOw3tFrwon5OGTd',
#  '4kYhmybjUNDIyuzf4KSSCy',
#  '3DqiRg6o1Sow9aC4zi7Pl1',
#  '0tA1QWTPcBl5qRRG8ImafH',
#  '49HF9spJ7OP3VORlEA6tZc',
#  '2MEqChwcFz1mumDuhgSymE',
#  '04N9dCUXxWWLaEZIXIZub2',
#  '033lkOlKbGU1R6d17hwIFp',
#  '3sOwbRqUDkhx3L5CyDGqfF',
#  '0xXYZ27p1yq2JhJN6Fw5kP',
#  '1AuUASK0ZzNRTb3n6JE34e',
#  '4H8ZNRyOta5NeKZePxKcV9',
#  '1a7gL2EKKBVDkivCbAUhix',
#  '0mdUSDWYwA3SlH3SGlxR3x',
#  '3zEymK9LZUIV0ec11bg387',
#  '6Uy4SUQ5pvte8whZnBzjBz',
#  '1ftQKRVk5btj8u1H75al2N',
#  '0zb5S00x0wtxOnsOc7nCLU',
#  '3l8oCDAnqQqg59ctkZFGHK',
#  '45Y9GLCmq4sFDm6V1fvQIo',
#  '41ZIWKRttvEWRK0NeBuNG8',
#  '4IhTMH0099WT36G7zmGNLw',
#  '0YDPj2YdV3R78S8Uv6MsyW',
#  '64GAvq1xe9wEwu5nXFajkZ',
#  '4RWggKYeVZfpeIM1htRNW8',
#  '5QZuV3Ueij8UkVj8JOGlcd',
#  '3YAaSyf97nrJkCBA9xIRaE',
#  '4Pjki6K9wvIQT3Ojb4RLXF',
#  '6rJquCo9cQEmzhw4slaysS',
#  '4TvA3wqlsewmxwK0Wfd75L',
#  '3YTJ3YrmU6XlEBUDvhjE0f',
#  '2Gy2TeHP1eV40KtDx0Od2I',
#  '2i2bUfEU6HE3VLbESFMEu7',
#  '4YCZg47v0UVOfrzSbB0PBh',
#  '6eEtOKTjtdlcE1urUecJeB',
#  '4DppGM42Nkckgnv4uJVLze',
#  '1BjttoCOsKvZvLIp34lCoX',
#  '1NoeamO4DRTd83jNIrR2Co',
#  '79dwy7RZi2IWDcZhwTNU6r',
#  '6dmiqCAqiwuyEnlm6WL1Eo',
#  '3Rv3q1XTj9G1fxwBMWEGqS',
#  '2HfpuAl4gaPsiI2V2GHDDe',
#  '6Q9p1R7TvehmDEyX8CnwJq',
#  '7FHEHZ5c4Jizsza4a0XZpi',
#  '1vSujkLsrFIziV2QHwm0pI',
#  '4K8Y6wsUKbJuvDDFE43z2h',
#  '42zhpu8Xp0SXEYfovshi97',
#  '5334XJ1zKCap88bh9vbNVJ',
#  '4eaaZ93X1UlGsZDOUMIq6f',
#  '7s3ZIaNsCzpX4bPer6HaAg',
#  '4n9CEd6rvubTtvmc4DUY5f',
#  '2sYV6f3ypT8ju161dRXqkF',
#  '7F3wlFVnJPcqCQYN2xZXca',
#  '4sL5LwxBW7YDdqLZo7Yots',
#  '1W1R8IFziSbdhEDfUuH3gd',
#  '3S7sh9GmNYnv7TPMW6GnTN',
#  '1ESUgD6zCsMT7QzfgssJXb',
#  '6LC7UCKvbg71Uqcwd4E0md',
#  '28X0zsuYYEtvRYY1b9i53h',
#  '00nnYw5Sj0DOsKpjlKcISa',
#  '1yzESxVhjj7dePQZVOu9oe',
#  '491rZB7bAmRXhkcY7gF1Vn',
#  '0Y70Q2vpsPKYQ3Bz7MC6Jj',
#  '4jv9ZGWoxIKzBY9kwqe9pj',
#  '588VeGBj9Ypo8DEJgs5L9m',
#  '6GnubxoOueiMgiBj8WTe3L',
#  '1UBQ5GK8JaQjm5VbkBZY66',
#  '6akKD20uUQsG7BbuPEJ5nG',
#  '2LHnjyFuMwVs7EIDdsHGiE',
#  '1C7OHsQG2zbmOeky9D6BSe',
#  '16sw9GImNiNypgRv7EHBv5',
#  '2QjMyGT8kkaIsyTwnbCaOK',
#  '1dTjP6xfrbf4xjSZzuRNg0',
#  '74VOzooxZgXbd6GS6ExcJP',
#  '7H1TOH8RWG8SIJ4FaXktI8',
#  '66TwGkIroxqhO8YnGfuFl5',
#  '0236WBuJgEyaeQsU82vyov',
#  '5Kkm5m3THLJAuFpJh66v65',
#  '7eKwYX7tAOZ8mExXilzSEb',
#  '5hnJa6971SqZRVvN2FJVCb',
#  '0La4dzhj6eakXkQBhqdpVW',
#  '5Ga1yLA8sTIzn3Y9IUmtuv',
#  '08vhhHTVDkWDV6BW8PuqGo',
#  '4HHzQ3QCbOWCIxFSM629x9',
#  '1QKWEOrj8Ee8PBu6mPVSw1',
#  '7GCnwd7SUrJc7ngw5aueGk',
#  '60b6heIvKzeiNobgicpURd',
#  '1uUH4NTpsSfMhQPVZ0MOCk',
#  '44CMPO3KKjkwxY13Y30dJJ',
#  '6EvY0HnUvZWmNjaaixLebv',
#  '3zCLGGhhmpIcQJtwnVxxff',
#  '3iIoH0OG9ylHBONGyCBrIW',
#  '6n6Ng3EWsJYFKOmgN38pcC',
#  '7ciiJfEJktpSwiLrksTDxa',
#  '5yemygKOs6SG3Kmw2H1mfn',
#  '1Hm3GGRXhc6N861Zh7z1JQ',
#  '0ElhE8wR7LU4ciUloFUNtq',
#  '4viTOOpSICB6dTJIi9Ub9T',
#  '3r8cXTaEwuWuOdNPw1GyH8',
#  '7s2XKw9if21DVy149xJ3Qj',
#  '2oIsB2Z35XKXkAeom9o7b4',
#  '6jDOZpBIOoViDknMvXy9Zb',
#  '1REsCrjEn9BhHov1nRZdNl',
#  '0TtKOHqlhWHCB3F7Vh3zt3',
#  '3oPaUXbnhxaqSr2Ilt6CB3',
#  '7hSs2rV43dUPnWIgBe9C2V',
#  '4p9NWwnNzOJ3cHsrcTNmca',
#  '5niaYz0IgeH03oyG1uXhYb',
#  '3wCXlLzKKucVyfVCvyVZqD',
#  '7nPBOsehBkh1AnZL4Szs6l',
#  '3KJABwmqJOTmzFrVaTwSlQ',
#  '5TV96lkS2NF6kzILjORzLs',
#  '7Lc39rObw7K3dvWAQDD4N2',
#  '5r6HatLjuMI44D76r5dNOo',
#  '6MGZkm9RcfxTONlFow4Lb6',
#  '2jA9ANFWZ4dM042Uln8Ky6',
#  '5OMePMBmfoRwvcW4AdGjzU',
#  '7sHEGjx0Zu3dN5StrdD14n',
#  '4vBTWN29Ur5vJQ575oc7Ri',
#  '7FBKLiVnYynElx7jlHyEJg',
#  '6B0g7kIHu1QNIKRo4a8DLW',
#  '5sutKkr2VcA06Nm17YG74u',
#  '1DlwdVqk1tRt0FrDRKha2t',
#  '3bZSVqYz11ByLWmSmAxO3c',
#  '5b4Djmjb9SN67dwkyBU7zr',
#  '4H7hEeXUkgiJCm7HtLgPaD',
#  '0IX9F7pVPv6egUgy2KxRIm',
#  '0npWMV3rlfHVB8LBUdCGP1',
#  '5Z8kZvVpjvgg8NuHKr9Ijs',
#  '0iuYY3NTZgKbatgcImKXo9',
#  '55K9dZaS89C8SV7DU8USSI',
#  '716QABy2MMurGzI3E8RkHf',
#  '3bMWlotbGJgNfgsLMZeip5',
#  '1zMuXA8SO9SpmP1oQQ9Sqi',
#  '3MFPUIRvswEXeYJCTjyF66',
#  '7LY8xxTkVhE6umWNHVIUx4',
#  '2dg2uSHYouI1BvFmNJ5iw6',
#  '4etE2X6t7GmyiuYLIdI8H5',
#  '3JEeOzrjZ4fP4uGNCzNlq1',
#  '0c6aqz1Djs13sHJxvAcOZJ',
#  '17Vj4GkH4yQYYewQNuWxLa',
#  '4pnbzeOFg5Tpm05GtCaoQk',
#  '2O1HKlrrc4wMsJRpNAh7Py',
#  '0KwsrQdsAuU3GhQ3OF63Ic',
#  '5nm45ZCDuHpyw3zQsPWcFw',
#  '2SvzzGJyZF7kuQGeA3WFKx',
#  '1OlWZR6C3g61tns8MtSm90',
#  '3WcmBT3Df6kSQuAJzzfGQv',
#  '16KNcQ8mx6pJAaawIxLsoT',
#  '58jR7PpMIHQuYked73xMqI',
#  '7bmf1sxzE9awRvOU8lGap2',
#  '0ZlNwlXfDUh8gxdUOXuc2F',
#  '0AKowThj9sCOLiNw2JNA4d',
#  '5AR5cm7Nr91AUjb7BX5MuG',
#  '4KB3YHxJOZ3jJPVa1PGcPm',
#  '5FvPXs0he4x8VIJlItD9Ze',
#  '3AQHeIR01vfmvRFYDAWdrg',
#  '2mX1iH7l5hgnZj5FataIPG',
#  '2X1Py69j5PBbvUJT6Sn9Eq',
#  '7tdyhRIrpfLwkzAga61w1Y',
#  '1chfLVdkUP07oL8fS3fUB0',
#  '3swNYNf70SR46EVXeHsIyo',
#  '5Alvgr4K6xbAlvF4HbeEJW',
#  '5fFjDIvHjN0cY5orODGzkq',
#  '456RQMHjX2tff4v9aLJ2Kn',
#  '4L7JuTcL7fKQErLSwzMeeJ',
#  '40ShrPuZdWPz99vwQMayXh',
#  '6Ht7ssT3Zs7UN4FsIospeg',
#  '4atTURtaWbsqJ1jqj0XMax',
#  '4xOoK1DhNbmomgVM70SO7q',
#  '7JUXlCANx4zVEH6FO35RiL',
#  '4FOcL9kAWIgAFAIZvvIjwe',
#  '2Rt38dOYRpvNB85nP4dMw5',
#  '0dckOJdWW8XymA07jxnIli',
#  '7ulZbaSRgamCIbVc77kGkq',
#  '0HnxmU3ltquFPg29Gq6VUn',
#  '7GuJ8WaaanwME1p0c4UJWq',
#  '1VrT2VYdFe9JeqlOiudS0P',
#  '3kRK88nusJ7vXz9MNDkWIZ',
#  '6g4ALmv2Udoj0Y7AoCVXJs',
#  '7CQLFJEyNHQEf1OWJe2dYJ',
#  '35PQEse5cSke0pJUS4ctPI',
#  '2XhQnU3XiGI4Pr3u9XWmz2',
#  '3h7iTYjPR88rXJlQinS6PI',
#  '1YQlKZKZNOXNC30aOekBUs',
#  '6zpKItStbFk3krHag9IiYa',
#  '1BI7O2x1UGZofgciMoE214',
#  '6hnmePY4p8hKULJAfCJkoG',
#  '6kl8gEF2XGdByoFwsuJFaK',
#  '3IrVfPYH2qbNxIAeuCrGU8',
#  '0IzkiCa6QAWLSBgyEdjiFH',
#  '2g7CTu2DZbkyNF6NwTQTN1',
#  '2UalVUgWOc21X12a9J2BOv',
#  '6l6u13PQYAa18sSkY27VyT',
#  '5NQJD4MJC6mTSOCHfK1I1s',
#  '4Byve9bVvCKP2va84g74cx',
#  '54NbOC5VweBsIJW2wrymcl',
#  '5vwuloCZYi0uIuafHZ3j0O',
#  '2MYSzXdvSPl9uGv0uJlcs3',
#  '0u489Lk3ZcahaPSw5SrjVf',
#  '7y3XDondxEHWe9sANzYs9l',
#  '6itDPZKJqL0KQxR1UVtOrl',
#  '65wXEvuayAMrw1HWbG033b',
#  '1bcj6xdNOULfBLHX5iiXOP',
#  '0EcdAa66tXUhXMkN8g87LU',
#  '4VXtpLkQ0VBPbvvJR23w2W',
#  '4iI2yKV3RFpTJQQ4CnuMJn',
#  '3eLxTH7BfdBwA3qzRGC61l',
#  '4G0gggK07BsKS9Ezr19OkH',
#  '6mJyM7FCZhFE8vmwEptpYc',
#  '3t2KmQzvv2W4Yo40uKi9HE',
#  '1J5kN69YwCFf5JT1VtWNBt',
#  '0btBlY6J9bXs8irvXsUSkJ',
#  '6tCh8Jmtj0ORFvYXfL9xcw',
#  '56Qkyuq8fr3grqSNiSyQaR',
#  '4Jgc1UGsizn7WhCU5q4Vvp',
#  '2LZCe1nGp21Rg6kJ2sDvuB',
#  '6YLMxHtXGVYUnhEXgUnkpj',
#  '60v2YOchVaaqmDzsZ9uszA',
#  '61p979vLhvTnrwI1FsfWR1',
#  '5Kc7FH6DARW0GuJuTv5Xj4',
#  '7IxScnyU9UNiZaoMUURQQt',
#  '6MKJtfmhG5TzFOFznUTW0f',
#  '7fSJD4FjK0xF9yqhgWL2Th',
#  '56h916BcB4467kRrELUh7f',
#  '3cUciy2Q2TduVqkxdvhXs5',
#  '28jjDhCAlgUXOD8jI0uPxn',
#  '09DLAR5Z5bvhrIoIIWG7ev',
#  '55MBolBQ2IdQS45T7EuAwp',
#  '59AqCglPDw5xYWEVq2ZVKw',
#  '6Ii96Kh1HP03QJuYB1cpyY',
#  '1rTqWPXLVdP9wVpVFHibou',
#  '3fxzah7uxPMyi1Os78NlON',
#  '2ArTVmBVbEUc38UXo5EQx6',
#  '32yAnn3IqODhXvR4s4NGhx',
#  '1W6UX3D4kXNHU4Jr17gO96',
#  '4cPVwiHcdCwr5bTTfCgvb7',
#  '5LE5WgZCYjZYDkrE6hVWij',
#  '64rKQaR1MnoL9QWns3vZvf',
#  '1u8HFZSjmPXB2sXdy8HAmm',
#  '08Qlr6KS3moEPZkPV0hheG',
#  '72PJuqVwp8aO1JfTEpTCIr',
#  '6JkmubBIA0HdWR0Cq4DXyd',
#  '1oSeS4VCu1Tzffs13SrqNP',
#  '34O7XKDLzvosUjEb8oBCtP',
#  '5rKhPplqkXS1i0QsDCpnGj',
#  '3vT4FAcaG2tIOompsnr2Ng',
#  '1460cYaBMDyUGW6nAmMQ8O',
#  '6NVUPcubuKSzicmPP5TGZl',
#  '4VYlQjU8Ms5YZe1JDqbCW0',
#  '5odE4cbxLKfosIxTJ25qmX',
#  '2obYlOGofygYwoQLjvQJz8',
#  '65nUhnl7C8cO1hz6C9vmEC',
#  '4Awq8flDPm0Cfcj9YW9BLu',
#  '1ailea5vP9YYKpGncs5whf',
#  '1c5TBby7e8YDVU61TsiK46',
#  '08GX7pf2XsmLGrgc4TaFJ6',
#  '4GkgLkOHvo89N6lDxARe8b',
#  '5hz8y5N1nSaGUoIy5Kk1Fb',
#  '7F4jFFsoXdmDUchFIfxFuh',
#  '35AvYbX2dX0eCaeyd9y0ib',
#  '3IFtheoYwZN2EQbsJgWaYP',
#  '7jTy6jHmgGmBeP4IeQsCit',
#  '52eL6oZUFlj6Gw9UI0OeIC',
#  '6SW2V3phE1Ng4m3p4TIXEn',
#  '3sgVCNPfm0UbHxbBJAU9jM',
#  '5ICy3IHIasc7bAeyHvVPwP',
#  '40hIeH5ISYC18Cz24mCATR',
#  '1GgN5mqbkuGHOZwaI8Gqnt',
#  '4AoEZfiroLYRCfuGpBxSVU',
#  '7hJjc5WQ5Xi8NyZSjRF7vB',
#  '18hXgfsVE04XnbKUivak1W',
#  '2yghkEAensB2jROWz2e82H',
#  '2N1JwzuwGRz4HadXCCDyNy',
#  '1M5PpoXpPDUBbapRYgnN9b',
#  '5FouFjjicO6dRDtupfNE27',
#  '5tng98F7aWT7mybOrVWJhQ',
#  '0BcRix2947l3Yi1ZFNlqNe',
#  '34W2z8kZzznc2QVaHccRgq',
#  '5yQ768vLDfXpbTQwOranKa',
#  '0ElOLX5pUiJXyPPFmApDqf',
#  '5Qbm6Y2k4Ig6eKa0pvr8CL',
#  '1MvTNHR0sBUv8M6C4gr65O',
#  '4PNKJAT9dhdvUOHfh8ND2P',
#  '29OZ54Zl8UHk69zbhuFNaA',
#  '7fduStNLh07yV8eJLRWWH9',
#  '2NkzQbRYG578YOlTrJv4ws',
#  '1wFE9XrTeGxRkMEgW0OcdZ',
#  '301A7ZeqFfLqX1IVPBFzov',
#  '7mRMqupbuoxELNop0AOmBk',
#  '3KPzKhuh7yq7TvnOn8NkKY',
#  '06Z6Zdd7ewCHfrPcnMbxhM',
#  '06pB2ZSKdpkB2cC0MLzeCs',
#  '5zT4MjZUYjIEXtEdtnCO5J',
#  '7eZ2LGJy0oKfqNR0Om4omo',
#  '3WQcDxcBdANAAcuWSu78xf',
#  '782huBltf7dvjD7cVks8Wr',
#  '2mnZbGi4pOhpw1FBvSKLkj',
#  ...]

# %%
song_id_list = pickle.load(open('./val_data/song_id_array.pkl', 'rb'))
song_id_list
# Out:
# array(['5PS5dpaLogPzYU9hWiWyZb', '41RpZW2lxAdnqDd2nMBzLQ',
#        '2poHURuOfVNbzZdivAwtOH', ..., '5Xo8AsEz0gpW6Rpo2jXvBN',
#        '4Fnz6vDqufd3ens0Gf9LC5', '2tolmRzbUfgL5KRplIqHlu'], dtype='<U22')
