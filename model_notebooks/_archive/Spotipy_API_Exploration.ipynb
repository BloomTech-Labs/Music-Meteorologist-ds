# %%
# !export SPOTIPY_CLIENT_ID='63594c9b2f99411a8cbd18df04851fc4'

# %%
# !export SPOTIPY_CLIENT_SECRET='096168b2bd1f4378ae410726955c9ed8'

# %%
# !export SPOTIPY_REDIRECT_URI='https://www.google.com/'

# %%
# ! SPOTIPY_CLIENT_ID
# Out:
# /bin/sh: SPOTIPY_CLIENT_ID: command not found

# %%
import os
import sys
import json
import spotipy
import webbrowser
import spotipy.util as util
from json.decoder import JSONDecodeError

USERNAME = 'rileypence4' #your spotify username
CLIENT_ID = '47c4f0d3dcaa433c9ef4ec6686e5b1f1' #set at your developer account
CLIENT_SECRET = '65812a5fb52b4a3486f59ec672d499ff' #set at your developer account
REDIRECT_URI = 'https://google.com/' #set at your developer account, usually "http://localhost:8000"
SCOPE = 'user-library-read' # or else
# ps. REDIRECT_URI is crucial here. if http://localhost:8000 is not set, or with a single '/' misplaced, it will generate a connection error.

# then pass them:

token = util.prompt_for_user_token(username = USERNAME, 
                                   scope = SCOPE, 
                                   client_id = CLIENT_ID, 
                                   client_secret = CLIENT_SECRET, 
                                   redirect_uri = REDIRECT_URI)

if token:
   sp = spotipy.Spotify(auth=token)
# Out:
#             User authentication requires interaction with your
#             web browser. Once you enter your credentials and
#             give authorization, you will be redirected to
#             a url.  Paste that url you were directed to to
#             complete the authorization.
#
#
# Opened https://accounts.spotify.com/authorize?client_id=47c4f0d3dcaa433c9ef4ec6686e5b1f1&response_type=code&redirect_uri=https%3A%2F%2Fgoogle.com%2F&scope=user-library-read in your browser
# Enter the URL you were redirected to:  https://www.google.com/?code=AQArxz5fMMI83TOZco5ymnBajJI7OGE5UkzHpncNpBJzg1rjFogCSjD3iM0yFq3zWakgFRhbva03BVZe4z3iupa8N-xDamTTK4X05lXr5TZU_TLseYfYpDsCqrP13D4uGjRuIFpbvf5zXzmHsTMZ5ZgpA8_OU2sFbfJrpOL3TNiFbUWYIRqd3Gocc4gVPacHl8I6kELkUXydjXkA

# %%
token
# Out:
# 'BQCEhCfQoAEwvw7muBWJ4fQmCKmB37d0a0PRz-FPGNHxXQjiW9YWECFFKXDYSrJ_Id_fKtA9rKnOUZJmrancJzmlxDPGBCzhQWNZ9sQK6FNfIlCyy81UVqUiWUT-2rOXkskvZXgjkqwamQMZ0Eu-3FbKxfOdxw'

# %%
sp = spotipy.Spotify(auth=token)
results = sp.current_user_saved_tracks()
for item in results['items']:
    track = item['track']
    song_id = item['track']['id']
    print (track['name'] + ' - ' + track['artists'][0]['name'])
    print (song_id)
# Out:
# Give Me A Reason - Hurshel
# 2MHuNy7E66luj3tjmLbXUr
# Lazy River - The Mills Brothers
# 2QEj9jE13oz8bnZABUAlDI
# Together - Element Six
# 3cfiHXIkMjftWTkmNic8zm
# I Want You Back - Berry Gordy
# 5Ysbm2Ee2V0TH7tQtAaYMN
# Jurassic Park Theme - John Williams
# 5F6nH9kNbB48FusY2hFH01
# Fathers' Eyes - The Piano Guys
# 12sBT9hQ7GE9X72Nbem1ty
# Soffia La Notte - Night Breaths - Fabrizio Paterlini
# 7Jkje7JNbeulTOCmYGiXYS
# Berceuse (Scaled Down Version) - Lo Mimieux
# 73xaHditQrP92Sia1pVvom

# %%
results
# Out:
# {'href': 'https://api.spotify.com/v1/me/tracks?offset=0&limit=20',
#  'items': [{'added_at': '2020-01-15T22:03:41Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6z6uBfaMCKFCDIuHNYhRra'},
#        'href': 'https://api.spotify.com/v1/artists/6z6uBfaMCKFCDIuHNYhRra',
#        'id': '6z6uBfaMCKFCDIuHNYhRra',
#        'name': 'Hurshel',
#        'type': 'artist',
#        'uri': 'spotify:artist:6z6uBfaMCKFCDIuHNYhRra'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5voS4tEgaZCmj0VFDZtQ68'},
#      'href': 'https://api.spotify.com/v1/albums/5voS4tEgaZCmj0VFDZtQ68',
#      'id': '5voS4tEgaZCmj0VFDZtQ68',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/525879c7b7137d7b23266f86f91ea6eb2040bfd6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/9bf8a47b0dec7c54e090198101cbbc79ad307ae1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/9d769a17f496e8e57db6b2d7f54c86ee32f28c1a',
#        'width': 64}],
#      'name': 'Give Me A Reason',
#      'release_date': '2019-12-25',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5voS4tEgaZCmj0VFDZtQ68'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6z6uBfaMCKFCDIuHNYhRra'},
#       'href': 'https://api.spotify.com/v1/artists/6z6uBfaMCKFCDIuHNYhRra',
#       'id': '6z6uBfaMCKFCDIuHNYhRra',
#       'name': 'Hurshel',
#       'type': 'artist',
#       'uri': 'spotify:artist:6z6uBfaMCKFCDIuHNYhRra'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 229333,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAKHO1913206'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2MHuNy7E66luj3tjmLbXUr'},
#     'href': 'https://api.spotify.com/v1/tracks/2MHuNy7E66luj3tjmLbXUr',
#     'id': '2MHuNy7E66luj3tjmLbXUr',
#     'is_local': False,
#     'name': 'Give Me A Reason',
#     'popularity': 37,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d4e4bd282c6405f68f014069c467fa84ab49f739?cid=47c4f0d3dcaa433c9ef4ec6686e5b1f1',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2MHuNy7E66luj3tjmLbXUr'}},
#   {'added_at': '2020-01-15T22:02:22Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v8bwWRbu7AI3YFhzoM6Ha'},
#        'href': 'https://api.spotify.com/v1/artists/5v8bwWRbu7AI3YFhzoM6Ha',
#        'id': '5v8bwWRbu7AI3YFhzoM6Ha',
#        'name': 'The Mills Brothers',
#        'type': 'artist',
#        'uri': 'spotify:artist:5v8bwWRbu7AI3YFhzoM6Ha'}],
#      'available_markets': ['CA', 'CR', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2XeteOkdPczBXOb05FTx44'},
#      'href': 'https://api.spotify.com/v1/albums/2XeteOkdPczBXOb05FTx44',
#      'id': '2XeteOkdPczBXOb05FTx44',
#      'images': [{'height': 629,
#        'url': 'https://i.scdn.co/image/688e8151d7b46377361258b83f859f29301f3b8c',
#        'width': 640},
#       {'height': 295,
#        'url': 'https://i.scdn.co/image/5ee338ede746b797823fca3c20e9a05b10e189cd',
#        'width': 300},
#       {'height': 63,
#        'url': 'https://i.scdn.co/image/a50d7e1c9e4078c416eb37888a7b0be3581cee38',
#        'width': 64}],
#      'name': 'Paper Doll',
#      'release_date': '1992-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:2XeteOkdPczBXOb05FTx44'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v8bwWRbu7AI3YFhzoM6Ha'},
#       'href': 'https://api.spotify.com/v1/artists/5v8bwWRbu7AI3YFhzoM6Ha',
#       'id': '5v8bwWRbu7AI3YFhzoM6Ha',
#       'name': 'The Mills Brothers',
#       'type': 'artist',
#       'uri': 'spotify:artist:5v8bwWRbu7AI3YFhzoM6Ha'}],
#     'available_markets': ['CA', 'CR', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 164304,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMC14169854'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2QEj9jE13oz8bnZABUAlDI'},
#     'href': 'https://api.spotify.com/v1/tracks/2QEj9jE13oz8bnZABUAlDI',
#     'id': '2QEj9jE13oz8bnZABUAlDI',
#     'is_local': False,
#     'name': 'Lazy River',
#     'popularity': 22,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4940c615f75d79ab0e878cb037d6de1e1684e828?cid=47c4f0d3dcaa433c9ef4ec6686e5b1f1',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2QEj9jE13oz8bnZABUAlDI'}},
#   {'added_at': '2017-11-28T00:54:50Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45YE6pBiok3lhq3ZK8AwwQ'},
#        'href': 'https://api.spotify.com/v1/artists/45YE6pBiok3lhq3ZK8AwwQ',
#        'id': '45YE6pBiok3lhq3ZK8AwwQ',
#        'name': 'Element Six',
#        'type': 'artist',
#        'uri': 'spotify:artist:45YE6pBiok3lhq3ZK8AwwQ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6UfFcMw9OOJ8lsadPkj4JF'},
#      'href': 'https://api.spotify.com/v1/albums/6UfFcMw9OOJ8lsadPkj4JF',
#      'id': '6UfFcMw9OOJ8lsadPkj4JF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731adc83f376d83c7e1512f12f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021adc83f376d83c7e1512f12f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511adc83f376d83c7e1512f12f',
#        'width': 64}],
#      'name': 'Together',
#      'release_date': '2017-03-17',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6UfFcMw9OOJ8lsadPkj4JF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45YE6pBiok3lhq3ZK8AwwQ'},
#       'href': 'https://api.spotify.com/v1/artists/45YE6pBiok3lhq3ZK8AwwQ',
#       'id': '45YE6pBiok3lhq3ZK8AwwQ',
#       'name': 'Element Six',
#       'type': 'artist',
#       'uri': 'spotify:artist:45YE6pBiok3lhq3ZK8AwwQ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 256875,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBKQU1722943'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3cfiHXIkMjftWTkmNic8zm'},
#     'href': 'https://api.spotify.com/v1/tracks/3cfiHXIkMjftWTkmNic8zm',
#     'id': '3cfiHXIkMjftWTkmNic8zm',
#     'is_local': False,
#     'name': 'Together',
#     'popularity': 7,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3095fa63b008c75399a7ed860fce7791b0f7af19?cid=47c4f0d3dcaa433c9ef4ec6686e5b1f1',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3cfiHXIkMjftWTkmNic8zm'}},
#   {'added_at': '2017-04-03T22:32:31Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6LTSK6whg1ZFZu6Uhk1S7P'},
#        'href': 'https://api.spotify.com/v1/artists/6LTSK6whg1ZFZu6Uhk1S7P',
#        'id': '6LTSK6whg1ZFZu6Uhk1S7P',
#        'name': 'Frederick Perren',
#        'type': 'artist',
#        'uri': 'spotify:artist:6LTSK6whg1ZFZu6Uhk1S7P'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7wjuWOChevyzU6GoTfo3LO'},
#        'href': 'https://api.spotify.com/v1/artists/7wjuWOChevyzU6GoTfo3LO',
#        'id': '7wjuWOChevyzU6GoTfo3LO',
#        'name': 'Alphonso Mizell',
#        'type': 'artist',
#        'uri': 'spotify:artist:7wjuWOChevyzU6GoTfo3LO'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#        'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#        'id': '5aIqB5nVVvmFsvSdExz408',
#        'name': 'Johann Sebastian Bach',
#        'type': 'artist',
#        'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4xRLKAf96K6YdGDWjY6ra8'},
#        'href': 'https://api.spotify.com/v1/artists/4xRLKAf96K6YdGDWjY6ra8',
#        'id': '4xRLKAf96K6YdGDWjY6ra8',
#        'name': 'Berry Gordy',
#        'type': 'artist',
#        'uri': 'spotify:artist:4xRLKAf96K6YdGDWjY6ra8'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/70Q1hGbTxHJYRqEvTYeoOw'},
#        'href': 'https://api.spotify.com/v1/artists/70Q1hGbTxHJYRqEvTYeoOw',
#        'id': '70Q1hGbTxHJYRqEvTYeoOw',
#        'name': 'Freddie Perren',
#        'type': 'artist',
#        'uri': 'spotify:artist:70Q1hGbTxHJYRqEvTYeoOw'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Rpq61lrW95EsZMlqMObli'},
#        'href': 'https://api.spotify.com/v1/artists/4Rpq61lrW95EsZMlqMObli',
#        'id': '4Rpq61lrW95EsZMlqMObli',
#        'name': 'Deke Richards',
#        'type': 'artist',
#        'uri': 'spotify:artist:4Rpq61lrW95EsZMlqMObli'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0jW6R8CVyVohuUJVcuweDI'},
#        'href': 'https://api.spotify.com/v1/artists/0jW6R8CVyVohuUJVcuweDI',
#        'id': '0jW6R8CVyVohuUJVcuweDI',
#        'name': 'The Piano Guys',
#        'type': 'artist',
#        'uri': 'spotify:artist:0jW6R8CVyVohuUJVcuweDI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5a7vLKSs4aC23TWkl9Bwa8'},
#      'href': 'https://api.spotify.com/v1/albums/5a7vLKSs4aC23TWkl9Bwa8',
#      'id': '5a7vLKSs4aC23TWkl9Bwa8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734147c034609352ba193231cc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024147c034609352ba193231cc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514147c034609352ba193231cc',
#        'width': 64}],
#      'name': 'I Want You Back',
#      'release_date': '2015-03-23',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5a7vLKSs4aC23TWkl9Bwa8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xRLKAf96K6YdGDWjY6ra8'},
#       'href': 'https://api.spotify.com/v1/artists/4xRLKAf96K6YdGDWjY6ra8',
#       'id': '4xRLKAf96K6YdGDWjY6ra8',
#       'name': 'Berry Gordy',
#       'type': 'artist',
#       'uri': 'spotify:artist:4xRLKAf96K6YdGDWjY6ra8'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#       'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#       'id': '5aIqB5nVVvmFsvSdExz408',
#       'name': 'Johann Sebastian Bach',
#       'type': 'artist',
#       'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7wjuWOChevyzU6GoTfo3LO'},
#       'href': 'https://api.spotify.com/v1/artists/7wjuWOChevyzU6GoTfo3LO',
#       'id': '7wjuWOChevyzU6GoTfo3LO',
#       'name': 'Alphonso Mizell',
#       'type': 'artist',
#       'uri': 'spotify:artist:7wjuWOChevyzU6GoTfo3LO'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LTSK6whg1ZFZu6Uhk1S7P'},
#       'href': 'https://api.spotify.com/v1/artists/6LTSK6whg1ZFZu6Uhk1S7P',
#       'id': '6LTSK6whg1ZFZu6Uhk1S7P',
#       'name': 'Frederick Perren',
#       'type': 'artist',
#       'uri': 'spotify:artist:6LTSK6whg1ZFZu6Uhk1S7P'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Rpq61lrW95EsZMlqMObli'},
#       'href': 'https://api.spotify.com/v1/artists/4Rpq61lrW95EsZMlqMObli',
#       'id': '4Rpq61lrW95EsZMlqMObli',
#       'name': 'Deke Richards',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Rpq61lrW95EsZMlqMObli'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/70Q1hGbTxHJYRqEvTYeoOw'},
#       'href': 'https://api.spotify.com/v1/artists/70Q1hGbTxHJYRqEvTYeoOw',
#       'id': '70Q1hGbTxHJYRqEvTYeoOw',
#       'name': 'Freddie Perren',
#       'type': 'artist',
#       'uri': 'spotify:artist:70Q1hGbTxHJYRqEvTYeoOw'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0jW6R8CVyVohuUJVcuweDI'},
#       'href': 'https://api.spotify.com/v1/artists/0jW6R8CVyVohuUJVcuweDI',
#       'id': '0jW6R8CVyVohuUJVcuweDI',
#       'name': 'The Piano Guys',
#       'type': 'artist',
#       'uri': 'spotify:artist:0jW6R8CVyVohuUJVcuweDI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 181022,
#     'explicit': False,
#     'external_ids': {'isrc': 'USQX91500510'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5Ysbm2Ee2V0TH7tQtAaYMN'},
#     'href': 'https://api.spotify.com/v1/tracks/5Ysbm2Ee2V0TH7tQtAaYMN',
#     'id': '5Ysbm2Ee2V0TH7tQtAaYMN',
#     'is_local': False,
#     'name': 'I Want You Back',
#     'popularity': 33,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a3e66907193f68d5926643630f418ac944a16b27?cid=47c4f0d3dcaa433c9ef4ec6686e5b1f1',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5Ysbm2Ee2V0TH7tQtAaYMN'}},
#   {'added_at': '2017-04-03T22:32:11Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3dRfiJ2650SZu6GbydcHNb'},
#        'href': 'https://api.spotify.com/v1/artists/3dRfiJ2650SZu6GbydcHNb',
#        'id': '3dRfiJ2650SZu6GbydcHNb',
#        'name': 'John Williams',
#        'type': 'artist',
#        'uri': 'spotify:artist:3dRfiJ2650SZu6GbydcHNb'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0jW6R8CVyVohuUJVcuweDI'},
#        'href': 'https://api.spotify.com/v1/artists/0jW6R8CVyVohuUJVcuweDI',
#        'id': '0jW6R8CVyVohuUJVcuweDI',
#        'name': 'The Piano Guys',
#        'type': 'artist',
#        'uri': 'spotify:artist:0jW6R8CVyVohuUJVcuweDI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0DeZzjVFrU1WjC29FJ5KKN'},
#      'href': 'https://api.spotify.com/v1/albums/0DeZzjVFrU1WjC29FJ5KKN',
#      'id': '0DeZzjVFrU1WjC29FJ5KKN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734fa3f70523d7ee7c016d199a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024fa3f70523d7ee7c016d199a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514fa3f70523d7ee7c016d199a',
#        'width': 64}],
#      'name': 'Main Title (From "Jurassic Park")',
#      'release_date': '2015-06-10',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0DeZzjVFrU1WjC29FJ5KKN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3dRfiJ2650SZu6GbydcHNb'},
#       'href': 'https://api.spotify.com/v1/artists/3dRfiJ2650SZu6GbydcHNb',
#       'id': '3dRfiJ2650SZu6GbydcHNb',
#       'name': 'John Williams',
#       'type': 'artist',
#       'uri': 'spotify:artist:3dRfiJ2650SZu6GbydcHNb'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0jW6R8CVyVohuUJVcuweDI'},
#       'href': 'https://api.spotify.com/v1/artists/0jW6R8CVyVohuUJVcuweDI',
#       'id': '0jW6R8CVyVohuUJVcuweDI',
#       'name': 'The Piano Guys',
#       'type': 'artist',
#       'uri': 'spotify:artist:0jW6R8CVyVohuUJVcuweDI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 235868,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11504966'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5F6nH9kNbB48FusY2hFH01'},
#     'href': 'https://api.spotify.com/v1/tracks/5F6nH9kNbB48FusY2hFH01',
#     'id': '5F6nH9kNbB48FusY2hFH01',
#     'is_local': False,
#     'name': 'Jurassic Park Theme',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/59dd097df5a29c210a7258235aacc8645f318123?cid=47c4f0d3dcaa433c9ef4ec6686e5b1f1',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5F6nH9kNbB48FusY2hFH01'}},
#   {'added_at': '2017-04-03T22:31:30Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jW6R8CVyVohuUJVcuweDI'},
#        'href': 'https://api.spotify.com/v1/artists/0jW6R8CVyVohuUJVcuweDI',
#        'id': '0jW6R8CVyVohuUJVcuweDI',
#        'name': 'The Piano Guys',
#        'type': 'artist',
#        'uri': 'spotify:artist:0jW6R8CVyVohuUJVcuweDI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1ezYUAyMAoiOnAu80UVzcS'},
#      'href': 'https://api.spotify.com/v1/albums/1ezYUAyMAoiOnAu80UVzcS',
#      'id': '1ezYUAyMAoiOnAu80UVzcS',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739090491b7692f055a8bee64a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029090491b7692f055a8bee64a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519090491b7692f055a8bee64a',
#        'width': 64}],
#      'name': 'Wonders',
#      'release_date': '2014-10-03',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:1ezYUAyMAoiOnAu80UVzcS'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jW6R8CVyVohuUJVcuweDI'},
#       'href': 'https://api.spotify.com/v1/artists/0jW6R8CVyVohuUJVcuweDI',
#       'id': '0jW6R8CVyVohuUJVcuweDI',
#       'name': 'The Piano Guys',
#       'type': 'artist',
#       'uri': 'spotify:artist:0jW6R8CVyVohuUJVcuweDI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 237186,
#     'explicit': False,
#     'external_ids': {'isrc': 'USQX91401627'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/12sBT9hQ7GE9X72Nbem1ty'},
#     'href': 'https://api.spotify.com/v1/tracks/12sBT9hQ7GE9X72Nbem1ty',
#     'id': '12sBT9hQ7GE9X72Nbem1ty',
#     'is_local': False,
#     'name': "Fathers' Eyes",
#     'popularity': 39,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0bec2c57059b1830d2a0414cbeb825fa7f4ebde4?cid=47c4f0d3dcaa433c9ef4ec6686e5b1f1',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:12sBT9hQ7GE9X72Nbem1ty'}},
#   {'added_at': '2017-04-03T22:26:36Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jrFMgW018F1XVnLtCXOKi'},
#        'href': 'https://api.spotify.com/v1/artists/0jrFMgW018F1XVnLtCXOKi',
#        'id': '0jrFMgW018F1XVnLtCXOKi',
#        'name': 'Fabrizio Paterlini',
#        'type': 'artist',
#        'uri': 'spotify:artist:0jrFMgW018F1XVnLtCXOKi'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/27Mqeyhg9ovUQrNdiKgrLz'},
#      'href': 'https://api.spotify.com/v1/albums/27Mqeyhg9ovUQrNdiKgrLz',
#      'id': '27Mqeyhg9ovUQrNdiKgrLz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27345ee78df54a47c1a8e0f8753',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0245ee78df54a47c1a8e0f8753',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485145ee78df54a47c1a8e0f8753',
#        'width': 64}],
#      'name': 'Viaggi In Aeromobile',
#      'release_date': '2007-11-16',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:27Mqeyhg9ovUQrNdiKgrLz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jrFMgW018F1XVnLtCXOKi'},
#       'href': 'https://api.spotify.com/v1/artists/0jrFMgW018F1XVnLtCXOKi',
#       'id': '0jrFMgW018F1XVnLtCXOKi',
#       'name': 'Fabrizio Paterlini',
#       'type': 'artist',
#       'uri': 'spotify:artist:0jrFMgW018F1XVnLtCXOKi'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 206453,
#     'explicit': False,
#     'external_ids': {'isrc': 'usx9p0783290'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7Jkje7JNbeulTOCmYGiXYS'},
#     'href': 'https://api.spotify.com/v1/tracks/7Jkje7JNbeulTOCmYGiXYS',
#     'id': '7Jkje7JNbeulTOCmYGiXYS',
#     'is_local': False,
#     'name': 'Soffia La Notte - Night Breaths',
#     'popularity': 4,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7Jkje7JNbeulTOCmYGiXYS'}},
#   {'added_at': '2017-04-03T22:26:10Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0M2jyp8P5yTxQcdPyCdDkM'},
#        'href': 'https://api.spotify.com/v1/artists/0M2jyp8P5yTxQcdPyCdDkM',
#        'id': '0M2jyp8P5yTxQcdPyCdDkM',
#        'name': 'Lo Mimieux',
#        'type': 'artist',
#        'uri': 'spotify:artist:0M2jyp8P5yTxQcdPyCdDkM'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3CapLnomeQByNOs4WBPOAZ'},
#      'href': 'https://api.spotify.com/v1/albums/3CapLnomeQByNOs4WBPOAZ',
#      'id': '3CapLnomeQByNOs4WBPOAZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273618f1847e8787109b9edd8c7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02618f1847e8787109b9edd8c7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851618f1847e8787109b9edd8c7',
#        'width': 64}],
#      'name': 'Berceuse',
#      'release_date': '2016-06-17',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:3CapLnomeQByNOs4WBPOAZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0M2jyp8P5yTxQcdPyCdDkM'},
#       'href': 'https://api.spotify.com/v1/artists/0M2jyp8P5yTxQcdPyCdDkM',
#       'id': '0M2jyp8P5yTxQcdPyCdDkM',
#       'name': 'Lo Mimieux',
#       'type': 'artist',
#       'uri': 'spotify:artist:0M2jyp8P5yTxQcdPyCdDkM'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 150688,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5Q51700285'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/73xaHditQrP92Sia1pVvom'},
#     'href': 'https://api.spotify.com/v1/tracks/73xaHditQrP92Sia1pVvom',
#     'id': '73xaHditQrP92Sia1pVvom',
#     'is_local': False,
#     'name': 'Berceuse (Scaled Down Version)',
#     'popularity': 8,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:73xaHditQrP92Sia1pVvom'}}],
#  'limit': 20,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 8}

# %%
results['items'][0]['track']['id']
# Out:
# '2MHuNy7E66luj3tjmLbXUr'

# %%
{token: 'BQCEhCfQoAEwvw7muBWJ4fQmCKmB37d0a0PRz-FPGNHxXQjiW9YWECFFKXDYSrJ_Id_fKtA9rKnOUZJmrancJzmlxDPGBCzhQWNZ9sQK6FNfIlCyy81UVqUiWUT-2rOXkskvZXgjkqwamQMZ0Eu-3FbKxfOdxw'}

# %%
def get_id(token):
    sp = spotipy.Spotify(auth=token)
    results = sp.current_user_saved_tracks()
    song_id = results['items'][0]['track']['id']
    return song_id

# %%
get_id(token)
# Out:
# '2MHuNy7E66luj3tjmLbXUr'

# %%
def get_features(song_id):
    results_dict = sp.audio_features(song_id)[0]
    audio_features = {"audio_features":{key: results_dict[key] for key in results_dict.keys() & {'danceability', 'energy',
                                                                                                'key', 'loudness', 'mode',
                                                                                                'speechiness', 'acousticness',
                                                                                                'instrumentalness', 'liveness',
                                                                                                'valence', 'tempo', 'time_signature'}}}
        
    return audio_features

# %%
get_features(get_id(token))
# Out:
# {'audio_features': {'valence': 0.388,
#   'key': 1,
#   'tempo': 179.802,
#   'mode': 0,
#   'liveness': 0.353,
#   'danceability': 0.386,
#   'instrumentalness': 0,
#   'loudness': -4.564,
#   'energy': 0.608,
#   'speechiness': 0.0528,
#   'acousticness': 0.38,
#   'time_signature': 4}}

# %%
results_dict = sp.audio_features('BQC-rkIS_d4ayUqDGJ4tqzQNEO5MCK4z-Mcs66TMcnMFKp58ScJhuQKy1gqRXqkgcesVQNnEy3DPBpQBLMO7ClzONag3AHYW_egb3ngAdfu6ORq88KQnWFjYKNTMTfuIJ_ZCImoiSb5MsP6U1-7JLKkf9zK9gw')[0]
    audio_features = {"audio_features":{key: results_dict[key] for key in results_dict.keys() & {'danceability', 'energy',
                                                                                                'key', 'loudness', 'mode',
                                                                                                'speechiness', 'acousticness',
                                                                                                'instrumentalness', 'liveness',
                                                                                                'valence', 'tempo', 'time_signature'}}}
# Out:
#   File "<ipython-input-42-d24569ca5071>", line 2
#     audio_features = {"audio_features":{key: results_dict[key] for key in results_dict.keys() & {'danceability', 'energy',
#     ^
# IndentationError: unexpected indent

# %%
# results = sp.search()

# q=artist%3Aqueen%20track%3Awe%20will%20rock%20you

# name = "Queen We Will Rock You"
artist = "Queen"
track = "We Will Rock You"
# query = f'q=artist:{artist}%20track:{track}&type=album'
results = sp.search(q='artist:' + artist + ' ' + 'track:' + track, type='track')
# results = sp.search(q='artist:' + name, type='track')
# results = sp.search(q=name, type='track')
results
# items = results['artists']['items']
# if len(items) > 0:
#     artist = items[0]
#     print(artist['name'], artist['images'][0]['url'])

# %%
# query=artist%3Aqueen+track%3Awe+will+rock+you&type=track&offset=0&limit=20"

# %%
results["tracks"]["items"][0]["id"]
# Out:
# '54flyrjcdnQdco7300avMJ'

# %%
for k,v in sp.audio_features('54flyrjcdnQdco7300avMJ')[0].items():
    print(k,v)
# Out:
# danceability 0.693
# energy 0.497
# key 2
# loudness -7.316
# mode 1
# speechiness 0.119
# acousticness 0.679
# instrumentalness 0
# liveness 0.258
# valence 0.473
# tempo 81.308
# type audio_features
# id 54flyrjcdnQdco7300avMJ
# uri spotify:track:54flyrjcdnQdco7300avMJ
# track_href https://api.spotify.com/v1/tracks/54flyrjcdnQdco7300avMJ
# analysis_url https://api.spotify.com/v1/audio-analysis/54flyrjcdnQdco7300avMJ
# duration_ms 122067
# time_signature 4

# %%
test_dict = sp.audio_features('54flyrjcdnQdco7300avMJ')[0]
{"audio_features":{key: test_dict[key] for key in test_dict.keys() & {'danceability', 'energy',
                                                                      'key', 'loudness', 'mode',
                                                                      'speechiness', 'acousticness',
                                                                      'instrumentalness', 'liveness',
                                                                      'valence', 'tempo', 'time_signature'}}}
# Out:
# {'audio_features': {'key': 2,
#   'instrumentalness': 0,
#   'time_signature': 4,
#   'energy': 0.497,
#   'liveness': 0.258,
#   'danceability': 0.693,
#   'mode': 1,
#   'acousticness': 0.679,
#   'tempo': 81.308,
#   'loudness': -7.316,
#   'valence': 0.473,
#   'speechiness': 0.119}}

# %%
import pandas as pd

song_list = pd.read_pickle("./song_list.pkl")

# %%
song_list.head()
# Out:
#                     0                   1                 2                  3
# 0  TRMMMYQ128F932D901  SOQMMHC12AB0180CB8  Faster Pussy cat       Silent Night
# 1  TRMMMKD128F425225D  SOVFVAK12A8C1350D9  Karkkiautomaatti        Tanssi vaan
# 2  TRMMMRX128F93187D9  SOGTUKN12AB017F4F1    Hudson Mohawke  No One Could Ever
# 3  TRMMMCH128F425532C  SOBNYVR12A8C13558C       Yerba Brava      Si Vos Querés
# 4  TRMMMWA128F426B589  SOHSBXH12A8C13B0DF        Der Mystic   Tangle Of Aspens

# %%
song_list = song_list.drop([0,1], axis=1)

# %%
song_list.head()
# Out:
#                   2                  3
# 0  Faster Pussy cat       Silent Night
# 1  Karkkiautomaatti        Tanssi vaan
# 2    Hudson Mohawke  No One Could Ever
# 3       Yerba Brava      Si Vos Querés
# 4        Der Mystic   Tangle Of Aspens

# %%
{'danceability': 0.693,
 'energy': 0.497,
 'key': 2,
 'loudness': -7.316,
 'mode': 1,
 'speechiness': 0.119,
 'acousticness': 0.679,
 'instrumentalness': 0,
 'liveness': 0.258,
 'valence': 0.473,
 'tempo': 81.308,
 'type': 'audio_features',
 'id': '54flyrjcdnQdco7300avMJ',
 'uri': 'spotify:track:54flyrjcdnQdco7300avMJ',
 'track_href': 'https://api.spotify.com/v1/tracks/54flyrjcdnQdco7300avMJ',
 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/54flyrjcdnQdco7300avMJ',
 'duration_ms': 122067,
 'time_signature': 4}
